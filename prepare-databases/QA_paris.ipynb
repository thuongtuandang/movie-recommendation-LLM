# %%
import json
import pandas as pd

# %%
file_path = '../data/movie_qa.csv'

# %%
# Correcting the error and completing the Q&A pairs
qa_pairs = [
    {"question": "Can you describe the theme of 'The Shawshank Redemption'?", "answer": "It's about hope, friendship, and the pursuit of freedom within the confines of a maximum-security prison."},
    {"question": "What is 'Inception' generally about?", "answer": "A sci-fi thriller centered around the concept of entering and manipulating people's dreams to steal or implant ideas."},
    {"question": "What can you tell me about 'The Godfather'?", "answer": "It's a crime drama focusing on the powerful Italian-American crime family of Don Vito Corleone. It explores themes of power, loyalty, and family dynamics."},
    {"question": "Describe the plot of 'Forrest Gump'.", "answer": "It follows the life of Forrest Gump, a man with a kind heart and low IQ, who witnesses and unwittingly influences several historical events in the 20th century America."},
    {"question": "What's the main idea of 'Interstellar'?", "answer": "A space exploration film that delves into themes of love, sacrifice, and survival, as astronauts travel through a wormhole in search of a new home for humanity."},
    {"question": "Can you describe 'Jurassic Park'?", "answer": "A sci-fi adventure where a theme park filled with cloned dinosaurs becomes a survival scenario when the creatures escape confinement."},
    {"question": "What is 'The Matrix' about?", "answer": "It explores a dystopian future in which reality as perceived by most humans is actually a simulated reality created by sentient machines."},
    {"question": "Describe the essence of 'Titanic'.", "answer": "A romantic disaster film that tells the tragic story of the RMS Titanic's ill-fated maiden voyage, intertwined with a love story between two passengers from different social classes."},
    {"question": "What's the plot of 'Avatar'?", "answer": "Set on the alien world of Pandora, it follows a paraplegic marine who becomes part of a project that involves controlling an avatar body and becomes torn between following orders and protecting the world's indigenous species."},
    {"question": "Can you explain the theme of 'Gladiator'?", "answer": "It's an epic historical drama about a Roman general who seeks vengeance against the corrupt emperor who murdered his family and sent him into slavery."},
    {"question": "What is 'Toy Story' about?", "answer": "An animated adventure where toys come to life when humans aren't around, focusing on the friendship between a cowboy doll named Woody and a space action figure, Buzz Lightyear."},
    {"question": "Describe 'Finding Nemo'.", "answer": "An animated film about a overprotective clownfish named Marlin who, along with a forgetful fish Dory, searches for his abducted son Nemo."},
    {"question": "What's the main idea behind 'Pulp Fiction'?", "answer": "A crime film known for its eclectic dialogue, ironic mix of humor and violence, and non-linear storyline, involving several Los Angeles criminals."},
    {"question": "Can you tell me about 'The Lion King'?", "answer": "An animated musical film about the journey of Simba, a lion prince who seeks to avenge his father's death and reclaim his kingdom."},
    {"question": "What is 'La La Land' generally about?", "answer": "A musical romance that follows a jazz musician and an aspiring actress who meet and fall in love in Los Angeles, but their ambitions threaten to tear them apart."},
    {"question": "Describe the theme of 'The Dark Knight'.", "answer": "A superhero film that explores the battle between Batman and his arch-nemesis, the Joker, set against the backdrop of Gotham City's fight against crime and corruption."},
    {"question": "What's 'Black Panther' about?", "answer": "A superhero film set in the fictional African nation of Wakanda, focusing on the reign of King T'Challa/Black Panther and the challenges to his sovereignty."},
    {"question": "Can you describe 'Get Out'?", "answer": "A horror film that tackles issues of race and racism through the story of a Black man visiting his white girlfriend's mysterious family estate."},
    {"question": "What is the essence of 'Mad Max: Fury Road'?", "answer": "A post-apocalyptic action film centered around a high-octane road war in a desert wasteland, focusing on survival and rebellion."},
    {"question": "Describe the plot of 'The Grand Budapest Hotel'.", "answer": "A comedy-drama that recounts the adventures of a legendary concierge at a famous European hotel between the wars, and the lobby boy who becomes his most trusted friend."},
]
df = pd.DataFrame(qa_pairs)
df.to_csv(file_path, index=False)
df.shape
# Out:
# (20, 2)

# %%
# Generating 20 unique Q&A pairs about movies in JSON format
qa_pairs= [
    {"question": "What central theme is explored in '12 Angry Men'?", "answer": "The importance of justice and the complexities of human nature in the jury system."},
    {"question": "How does '2001: A Space Odyssey' address the evolution of mankind?", "answer": "Through a narrative that spans from the dawn of man to space exploration, it explores human progress and its relationship with technology."},
    {"question": "What moral lessons are conveyed through 'Finding Dory'?", "answer": "Themes of friendship, perseverance, and the value of family, regardless of biological ties."},
    {"question": "Why has 'The Big Lebowski' maintained its cult status over the years?", "answer": "Due to its unique characters, memorable dialogue, and its blend of humor and noir elements."},
    {"question": "How does 'Gone with the Wind' portray the American Civil War and its aftermath?", "answer": "Through the eyes of Scarlett O'Hara, depicting the impact of war on the South's aristocratic society."},
    {"question": "What was Steven Spielberg's directorial debut, and how did it impact his career?", "answer": "'Duel', a thriller that established his ability to create suspense and led to a successful career in filmmaking."},
    {"question": "What made 'Moonlight' a notable entry in the drama film genre?", "answer": "Its exploration of African-American identity, sexuality, and the challenges of growing up in a rough neighborhood."},
    {"question": "Which movie is considered a pioneering work in the science fiction genre, and why?", "answer": "'Metropolis', for its futuristic setting and themes of class struggle, was ahead of its time."},
    {"question": "Can you name a film that significantly influenced the development of modern independent cinema?", "answer": "'Pulp Fiction', with its unique narrative structure and blend of dialogue and violence."},
    {"question": "What are some standout features of 'Cinema Paradiso' that contribute to its popularity?", "answer": "Its nostalgic portrayal of film's impact on a small Italian village and the power of cinema to bring people together."},
    {"question": "How does 'The Social Network' explore the creation of Facebook?", "answer": "By focusing on the legal and personal challenges faced by Mark Zuckerberg during the rise of Facebook."},
    {"question": "What is the main theme of 'Life of Pi'?", "answer": "Survival, spirituality, and the human connection with animals, explored through the protagonist's journey at sea."},
    {"question": "Why is 'Casablanca' considered a classic in film history?", "answer": "For its romantic storyline, memorable quotes, and depiction of wartime sacrifice."},
    {"question": "What distinguishes 'Spirited Away' in the animated film genre?", "answer": "Its rich visual storytelling, depth of characters, and exploration of themes like greed and innocence."},
    {"question": "Why has 'Fight Club' become a cultural icon?", "answer": "For its critique of consumerism, identity, and societal norms, packaged in a darkly comedic narrative."},
    {"question": "How does 'The Grand Budapest Hotel' use visual style to enhance its storytelling?", "answer": "Through meticulous set designs, colorful palettes, and symmetrical compositions that complement the whimsical narrative."},
    {"question": "What makes 'A Clockwork Orange' a controversial film?", "answer": "Its graphic violence and exploration of themes like free will and the nature of evil."},
    {"question": "Why is 'Vertigo' considered a masterpiece in psychological thriller genre?", "answer": "For its complex narrative, themes of obsession and identity, and innovative use of camera techniques."},
    {"question": "How does 'Amelie' stand out in the romantic comedy genre?", "answer": "Through its whimsical portrayal of Paris, charming protagonist, and unique visual style."},
    {"question": "What is the significance of 'The Silence of the Lambs' in the thriller genre?", "answer": "For its psychological depth, memorable characters, and blending of horror and detective elements."}
]

df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (40, 2)

# %%
# Generating another set of 20 unique Q&A pairs about movies, focusing on general descriptions and themes
qa_pairs = [
    {"question": "What themes does 'Braveheart' explore?", "answer": "Freedom, bravery, and the fight for independence against oppression."},
    {"question": "Describe the central conflict in 'The Terminator'.", "answer": "The battle between humans and machines in a post-apocalyptic future."},
    {"question": "What is the premise of 'The Truman Show'?", "answer": "A man discovers his entire life is a reality TV show."},
    {"question": "What is 'Memento' about?", "answer": "A man with short-term memory loss uses notes and tattoos to hunt for his wife's murderer."},
    {"question": "Can you explain the plot of 'Slumdog Millionaire'?", "answer": "A Mumbai teen reflects on his upbringing in the slums when he is accused of cheating on the Indian version of 'Who Wants to be a Millionaire?'."},
    {"question": "What's the story behind 'The Great Gatsby'?", "answer": "A critique of the American Dream through the tragic story of Jay Gatsby, a man who obsesses over his past love."},
    {"question": "Describe the narrative of 'Pan's Labyrinth'.", "answer": "In post-Civil War Spain, a young girl escapes into a mythical world to deal with the realities of her harsh life."},
    {"question": "What makes 'The Prestige' unique?", "answer": "Its exploration of obsession, sacrifice, and the costs of magical rivalry."},
    {"question": "How does 'WALL-E' comment on society?", "answer": "Through a story of a waste-collecting robot, it addresses consumerism, environmental neglect, and the search for genuine connection."},
    {"question": "What is the central theme of 'Up'?", "answer": "Adventure and dealing with loss, as an elderly widower sets off on an adventure in his flying house."},
    {"question": "Describe 'The Help's' primary focus.", "answer": "Racial tensions and the civil rights movement in the 1960s Mississippi, through the lens of black maids working in white households."},
    {"question": "What conflict drives 'The Hunger Games'?", "answer": "A dystopian society's televised event where children fight to the death, highlighting themes of survival, tyranny, and resistance."},
    {"question": "Can you outline 'Ratatouille's' plot?", "answer": "A rat with a passion for cooking makes an unusual alliance with a young kitchen worker at a famous restaurant."},
    {"question": "What is the essence of 'Dead Poets Society'?", "answer": "The impact of an unconventional teacher on his students and the encouragement to 'seize the day'."},
    {"question": "How does 'The Notebook' depict its central theme?", "answer": "Through a decades-spanning romance, it explores themes of love, memory, and loss."},
    {"question": "What is 'A Beautiful Mind' about?", "answer": "The life of John Nash, a brilliant but asocial mathematician, and his battle with schizophrenia."},
    {"question": "Describe the setting of 'Blade Runner 2049'.", "answer": "A dystopian future where a new blade runner uncovers a long-buried secret that has the potential to plunge society into chaos."},
    {"question": "What themes are explored in 'Moonrise Kingdom'?", "answer": "First love, adventure, and the innocence of youth set against the backdrop of a quirky island community."},
    {"question": "Can you explain 'The Grand Budapest Hotel's' appeal?", "answer": "Its unique storytelling, visual style, and the portrayal of a concierge's adventures in a famous European hotel."},
    {"question": "What is 'Her' about?", "answer": "A man develops an unexpected relationship with an operating system designed to meet his every need."}
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (60, 2)

# %%
# Generating an additional set of 20 unique Q&A pairs about movies, focusing on themes and general descriptions
qa_pairs_final = [
    {"question": "What is the primary theme of 'The Color Purple'?", "answer": "The struggle of African American women in the early 20th century."},
    {"question": "How does 'The Shape of Water' blend genres?", "answer": "It combines fantasy, romance, and historical drama set against the backdrop of the Cold War era."},
    {"question": "What's the premise of 'Eternal Sunshine of the Spotless Mind'?", "answer": "A couple undergoes a procedure to erase memories of their relationship when it turns sour."},
    {"question": "Describe the narrative focus of 'Gone Girl'.", "answer": "The disappearance of a woman and the subsequent media frenzy and suspicion on her husband."},
    {"question": "What makes 'The Revenant' unique in terms of setting and theme?", "answer": "Its depiction of survival and revenge in the American wilderness during the 1820s."},
    {"question": "Can you explain the appeal of 'Whiplash'?", "answer": "The intense relationship between an ambitious jazz drummer and his abusive instructor."},
    {"question": "What is 'Silver Linings Playbook' about?", "answer": "A man with bipolar disorder trying to reclaim his life and reconcile with his ex-wife, finding solace in a new friendship."},
    {"question": "How does 'Little Women' explore the themes of sisterhood and ambition?", "answer": "Through the lives and relationships of the March sisters as they come of age in post-Civil War America."},
    {"question": "Describe the central conflict in 'No Country for Old Men'.", "answer": "A hunter finds a fortune in drug money, setting off a violent chain reaction pursued by a relentless hitman."},
    {"question": "What is 'The Grand Budapest Hotel' known for?", "answer": "Its unique storytelling, visual style, and the portrayal of a concierge's adventures in a famous European hotel."},
    {"question": "How does 'Mad Max: Fury Road' reimagine dystopian themes?", "answer": "Through high-octane chases and battles in a desert wasteland, emphasizing survival and rebellion."},
    {"question": "What's the central theme of 'Birdman'?", "answer": "The quest for relevance and artistic integrity in the life of a washed-up actor."},
    {"question": "Can you describe the plot of 'Brooklyn'?", "answer": "An Irish immigrant navigates her life in 1950s Brooklyn, torn between her new home and her past in Ireland."},
    {"question": "How does 'Dunkirk' present its WWII narrative?", "answer": "By immersively depicting the evacuation of Allied soldiers from Dunkirk, focusing on survival and heroism."},
    {"question": "What is the essence of 'Call Me by Your Name'?", "answer": "A coming-of-age story about a teenager's summer romance with a visiting scholar in Italy."},
    {"question": "Describe 'The Theory of Everything'.", "answer": "The life of Stephen Hawking, focusing on his groundbreaking work and battle with ALS."},
    {"question": "What makes 'Arrival' a unique science fiction film?", "answer": "Its focus on language and communication with aliens, exploring themes of time, memory, and connection."},
    {"question": "How does 'Moonlight' address the theme of identity?", "answer": "Through the life of a young African-American man grappling with his identity and sexuality."},
    {"question": "Can you outline the themes of 'Lady Bird'?", "answer": "Adolescence, mother-daughter relationships, and the quest for identity."},
    {"question": "What is 'Parasite' about?", "answer": "A poor family's scheme to become employed by a wealthy family, leading to unexpected consequences."}
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (80, 2)

# %%
qa_pairs = [
  {
    "question": "What is the basic plot of the movie Titanic?",
    "answer": "Titanic follows the ill-fated voyage of the RMS Titanic, focusing on the romance between passengers Jack and Rose."
  },
  {
    "question": "In the movie Forrest Gump, what is the main theme?",
    "answer": "Forrest Gump explores themes of destiny, love, and the American experience through the life of its titular character."
  },
  {
    "question": "What is the central theme of The Shawshank Redemption?",
    "answer": "The Shawshank Redemption explores themes of hope, friendship, and the resilience of the human spirit in the face of adversity."
  },
  {
    "question": "What is the main conflict in The Godfather?",
    "answer": "The Godfather revolves around the conflict within the Corleone crime family and their struggle for power and control."
  },
  {
    "question": "What is the central message of the movie Fight Club?",
    "answer": "Fight Club delves into themes of consumerism, masculinity, and the search for meaning in modern society."
  },
  {
    "question": "What is the central theme of the movie Inception?",
    "answer": "Inception explores the nature of reality, the power of dreams, and the complexity of the human mind."
  },
  {
    "question": "What is the primary focus of the movie The Matrix?",
    "answer": "The Matrix focuses on the concept of reality versus illusion, questioning the nature of existence and the control of technology."
  },
  {
    "question": "What is the central conflict in the movie The Silence of the Lambs?",
    "answer": "The Silence of the Lambs revolves around FBI agent Clarice Starling's pursuit of the serial killer Buffalo Bill, with the assistance of incarcerated cannibalistic psychiatrist Dr. Hannibal Lecter."
  },
  {
    "question": "What themes does the movie The Dark Knight explore?",
    "answer": "The Dark Knight delves into themes of chaos versus order, the nature of heroism, and the thin line between good and evil."
  },
  {
    "question": "What is the main theme of the movie Interstellar?",
    "answer": "Interstellar explores themes of love, sacrifice, and the survival of humanity in the face of extinction."
  },
  {
    "question": "What is the central message of the movie Pulp Fiction?",
    "answer": "Pulp Fiction explores themes of crime, redemption, and the interconnectivity of seemingly unrelated events."
  },
  {
    "question": "What is the main theme of the movie The Lord of the Rings: The Fellowship of the Ring?",
    "answer": "The Fellowship of the Ring focuses on themes of friendship, courage, and the struggle against evil."
  },
  {
    "question": "What themes are explored in the movie Blade Runner?",
    "answer": "Blade Runner delves into themes of identity, humanity, and the consequences of advanced technology."
  },
  {
    "question": "What is the central conflict in the movie Gladiator?",
    "answer": "Gladiator centers on the struggle of Maximus Decimus Meridius to avenge his family and seek justice against the corrupt emperor Commodus."
  },
  {
    "question": "What themes does the movie Schindler's List address?",
    "answer": "Schindler's List addresses themes of compassion, humanity, and the horrors of the Holocaust."
  },
  {
    "question": "What is the central theme of the movie Good Will Hunting?",
    "answer": "Good Will Hunting explores themes of self-discovery, intellect, and the power of human connection."
  },
  {
    "question": "What is the main focus of the movie Avatar?",
    "answer": "Avatar focuses on themes of environmentalism, imperialism, and the clash of civilizations."
  },
  {
    "question": "What themes are prevalent in the movie The Truman Show?",
    "answer": "The Truman Show explores themes of reality versus illusion, free will, and media manipulation."
  },
  {
    "question": "What is the central theme of the movie The Departed?",
    "answer": "The Departed examines themes of loyalty, betrayal, and the blurred lines between law enforcement and organized crime."
  },
  {
    "question": "What is the primary theme of the movie The Social Network?",
    "answer": "The Social Network explores themes of ambition, friendship, and the impact of technology on human relationships."
  },
  {
    "question": "What themes are explored in the movie The Prestige?",
    "answer": "The Prestige delves into themes of obsession, sacrifice, and the nature of deception."
  },
  {
    "question": "What is the main theme of the movie Eternal Sunshine of the Spotless Mind?",
    "answer": "Eternal Sunshine of the Spotless Mind explores themes of love, memory, and the consequences of erasing painful experiences."
  },
  {
    "question": "What themes does the movie American Beauty tackle?",
    "answer": "American Beauty addresses themes of beauty, dissatisfaction, and the search for meaning in suburban life."
  },
  {
    "question": "What is the central message of the movie No Country for Old Men?",
    "answer": "No Country for Old Men explores themes of fate, morality, and the inevitable consequences of violence."
  },
  {
    "question": "What is the main focus of the movie The Revenant?",
    "answer": "The Revenant focuses on themes of survival, revenge, and the resilience of the human spirit in the wilderness."
  },
  {
    "question": "What themes does the movie Arrival explore?",
    "answer": "Arrival delves into themes of communication, time, and the nature of human perception."
  },
  {
    "question": "What is the central theme of the movie La La Land?",
    "answer": "La La Land explores themes of dreams, love, and the pursuit of artistic ambition."
  },
  {
    "question": "What is the primary focus of the movie The Green Mile?",
    "answer": "The Green Mile focuses on themes of redemption, compassion, and the supernatural."
  },
  {
    "question": "What themes are prevalent in the movie Requiem for a Dream?",
    "answer": "Requiem for a Dream explores themes of addiction, dreams, and the consequences of pursuing an idealized life."
  },
  {
    "question": "What is the central theme of the movie 12 Angry Men?",
    "answer": "12 Angry Men examines themes of justice, prejudice, and the power of dialogue and persuasion."
  },
  {
    "question": "What is the main focus of the movie The Sixth Sense?",
    "answer": "The Sixth Sense focuses on themes of perception, grief, and the supernatural."
  }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (111, 2)

# %%
qa_pairs = [
  {
    "question": "What themes are explored in the movie The Shawshank Redemption?",
    "answer": "The Shawshank Redemption explores themes of hope, friendship, and the resilience of the human spirit in the face of injustice."
  },
  {
    "question": "What is the central theme of the movie The Godfather?",
    "answer": "The Godfather delves into themes of power, loyalty, and the consequences of choices in a criminal underworld."
  },
  {
    "question": "What is the main focus of the movie Fight Club?",
    "answer": "Fight Club focuses on themes of disillusionment with modern society, identity, and the quest for freedom."
  },
  {
    "question": "What is the primary theme of the movie Inception?",
    "answer": "Inception explores themes of reality manipulation, guilt, and the subconscious mind."
  },
  {
    "question": "What is the main theme of the movie The Matrix?",
    "answer": "The Matrix examines themes of reality, control, and the nature of existence in a simulated world."
  },
  {
    "question": "What themes are prevalent in the movie The Silence of the Lambs?",
    "answer": "The Silence of the Lambs explores themes of psychology, manipulation, and the darkness of the human psyche."
  },
  {
    "question": "What is the central conflict in the movie The Dark Knight?",
    "answer": "The Dark Knight centers on the conflict between chaos represented by the Joker and order represented by Batman."
  },
  {
    "question": "What is the main theme of the movie Interstellar?",
    "answer": "Interstellar delves into themes of exploration, love, and the survival of humanity in a vast and unknown universe."
  },
  {
    "question": "What is the central message of the movie Pulp Fiction?",
    "answer": "Pulp Fiction explores themes of redemption, morality, and the interconnectedness of seemingly unrelated events."
  },
  {
    "question": "What is the main theme of the movie The Lord of the Rings: The Fellowship of the Ring?",
    "answer": "The Fellowship of the Ring focuses on themes of friendship, heroism, and the battle between good and evil."
  },
  {
    "question": "What themes are explored in the movie Blade Runner?",
    "answer": "Blade Runner delves into themes of identity, humanity, and the ethical implications of artificial intelligence."
  },
  {
    "question": "What is the central conflict in the movie Gladiator?",
    "answer": "Gladiator revolves around the conflict between Maximus and Commodus, exploring themes of revenge, honor, and justice."
  },
  {
    "question": "What themes does the movie Schindler's List address?",
    "answer": "Schindler's List addresses themes of compassion, morality, and the resilience of the human spirit in the face of atrocity."
  },
  {
    "question": "What is the central theme of the movie Good Will Hunting?",
    "answer": "Good Will Hunting explores themes of intellect, identity, and the transformative power of human connection."
  },
  {
    "question": "What is the main focus of the movie Avatar?",
    "answer": "Avatar focuses on themes of environmentalism, colonialism, and the interconnectedness of all living beings."
  },
  {
    "question": "What themes are prevalent in the movie The Truman Show?",
    "answer": "The Truman Show explores themes of reality, freedom, and the ethics of media manipulation."
  },
  {
    "question": "What is the central theme of the movie The Departed?",
    "answer": "The Departed examines themes of loyalty, betrayal, and the blurred lines between good and evil in the criminal underworld."
  },
  {
    "question": "What is the primary theme of the movie The Social Network?",
    "answer": "The Social Network explores themes of ambition, betrayal, and the impact of technology on human relationships."
  },
  {
    "question": "What themes are explored in the movie The Prestige?",
    "answer": "The Prestige delves into themes of obsession, sacrifice, and the nature of rivalry in the pursuit of greatness."
  },
  {
    "question": "What is the main theme of the movie Eternal Sunshine of the Spotless Mind?",
    "answer": "Eternal Sunshine of the Spotless Mind explores themes of memory, love, and the inevitability of heartbreak."
  },
  {
    "question": "What themes does the movie American Beauty tackle?",
    "answer": "American Beauty addresses themes of beauty, conformity, and the emptiness of suburban life."
  },
  {
    "question": "What is the central message of the movie No Country for Old Men?",
    "answer": "No Country for Old Men explores themes of fate, morality, and the inexorable march of time."
  },
  {
    "question": "What is the main focus of the movie The Revenant?",
    "answer": "The Revenant focuses on themes of survival, revenge, and the primal instincts of humanity."
  },
  {
    "question": "What themes does the movie Arrival explore?",
    "answer": "Arrival delves into themes of communication, time, and the nature of language in shaping our perception of reality."
  },
  {
    "question": "What is the central theme of the movie La La Land?",
    "answer": "La La Land explores themes of dreams, love, and the pursuit of artistic fulfillment in the face of practical realities."
  },
  {
    "question": "What is the primary focus of the movie The Green Mile?",
    "answer": "The Green Mile focuses on themes of compassion, redemption, and the supernatural elements of human nature."
  },
  {
    "question": "What themes are prevalent in the movie Requiem for a Dream?",
    "answer": "Requiem for a Dream explores themes of addiction, delusion, and the destructive pursuit of the American Dream."
  },
  {
    "question": "What is the central theme of the movie 12 Angry Men?",
    "answer": "12 Angry Men examines themes of justice, prejudice, and the power of moral integrity in the face of societal pressures."
  },
  {
    "question": "What is the main focus of the movie The Sixth Sense?",
    "answer": "The Sixth Sense focuses on themes of perception, grief, and the search for meaning beyond the veil of death."
  }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (140, 2)

# %%
qa_pairs = [
  {
    "question": "What is the central theme of the movie The Grand Budapest Hotel?",
    "answer": "The Grand Budapest Hotel explores themes of nostalgia, friendship, and the passage of time."
  },
  {
    "question": "What is the primary focus of the movie Her?",
    "answer": "Her focuses on themes of loneliness, connection, and the evolving relationship between humans and technology."
  },
  {
    "question": "What themes are prevalent in the movie The Shape of Water?",
    "answer": "The Shape of Water explores themes of love, acceptance, and the beauty of unconventional relationships."
  },
  {
    "question": "What is the main theme of the movie Arrival?",
    "answer": "Arrival delves into themes of communication, understanding, and the consequences of misinterpretation."
  },
  {
    "question": "What is the central message of the movie Birdman?",
    "answer": "Birdman examines themes of identity, ego, and the pursuit of artistic validation."
  },
  {
    "question": "What themes does the movie Black Swan address?",
    "answer": "Black Swan explores themes of perfection, obsession, and the psychological toll of pursuing excellence."
  },
  {
    "question": "What is the main focus of the movie Lost in Translation?",
    "answer": "Lost in Translation focuses on themes of loneliness, connection, and cultural dislocation."
  },
  {
    "question": "What themes are explored in the movie The Truman Show?",
    "answer": "The Truman Show addresses themes of reality versus illusion, free will, and the quest for authenticity."
  },
  {
    "question": "What is the central theme of the movie The Lobster?",
    "answer": "The Lobster explores themes of love, conformity, and the pressures of societal expectations."
  },
  {
    "question": "What is the primary theme of the movie Eternal Sunshine of the Spotless Mind?",
    "answer": "Eternal Sunshine of the Spotless Mind delves into themes of memory, love, and the human desire to erase painful experiences."
  },
  {
    "question": "What themes does the movie Moonlight tackle?",
    "answer": "Moonlight addresses themes of identity, sexuality, and the search for self-acceptance."
  },
  {
    "question": "What is the central message of the movie Drive?",
    "answer": "Drive explores themes of existentialism, violence, and the consequences of a solitary existence."
  },
  {
    "question": "What is the main theme of the movie La La Land?",
    "answer": "La La Land explores themes of dreams, love, and the pursuit of artistic ambition."
  },
  {
    "question": "What themes are prevalent in the movie Pan's Labyrinth?",
    "answer": "Pan's Labyrinth explores themes of fantasy, rebellion, and the power of imagination in the face of oppression."
  },
  {
    "question": "What is the central theme of the movie Hereditary?",
    "answer": "Hereditary delves into themes of grief, family secrets, and the legacy of trauma."
  },
  {
    "question": "What is the primary focus of the movie The Revenant?",
    "answer": "The Revenant focuses on themes of survival, revenge, and the resilience of the human spirit."
  },
  {
    "question": "What themes does the movie A Clockwork Orange address?",
    "answer": "A Clockwork Orange explores themes of free will, morality, and the consequences of societal control."
  },
  {
    "question": "What is the main focus of the movie Interstellar?",
    "answer": "Interstellar focuses on themes of love, sacrifice, and the exploration of the unknown."
  },
  {
    "question": "What themes are explored in the movie Donnie Darko?",
    "answer": "Donnie Darko addresses themes of time travel, existentialism, and the search for meaning in a chaotic world."
  },
  {
    "question": "What is the central theme of the movie The Shape of Water?",
    "answer": "The Shape of Water explores themes of love, acceptance, and the triumph of the human spirit over prejudice."
  },
  {
    "question": "What is the primary theme of the movie 500 Days of Summer?",
    "answer": "500 Days of Summer examines themes of love, heartbreak, and the complexities of romantic relationships."
  },
  {
    "question": "What themes are prevalent in the movie The Truman Show?",
    "answer": "The Truman Show addresses themes of reality versus illusion, free will, and the nature of personal agency."
  },
  {
    "question": "What is the central message of the movie Eternal Sunshine of the Spotless Mind?",
    "answer": "Eternal Sunshine of the Spotless Mind explores themes of memory, love, and the human desire to erase painful experiences."
  },
  {
    "question": "What is the main theme of the movie Lost in Translation?",
    "answer": "Lost in Translation explores themes of loneliness, connection, and the transient nature of human relationships."
  },
  {
    "question": "What themes does the movie Mulholland Drive tackle?",
    "answer": "Mulholland Drive addresses themes of identity, illusion, and the blurred lines between reality and fantasy."
  },
  {
    "question": "What is the central theme of the movie A Ghost Story?",
    "answer": "A Ghost Story explores themes of grief, time, and the enduring power of love."
  },
  {
    "question": "What is the primary focus of the movie The Master?",
    "answer": "The Master focuses on themes of power, control, and the search for meaning in a post-war America."
  },
  {
    "question": "What themes are explored in the movie Blade Runner 2049?",
    "answer": "Blade Runner 2049 delves into themes of identity, memory, and the consequences of playing god with artificial life."
  },
  {
    "question": "What is the central theme of the movie Eternal Sunshine of the Spotless Mind?",
    "answer": "Eternal Sunshine of the Spotless Mind explores themes of memory, love, and the human desire to erase painful experiences."
  },
  {
    "question": "What is the main focus of the movie Blue Valentine?",
    "answer": "Blue Valentine focuses on themes of love, loss, and the disintegration of a relationship over time."
  }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (170, 2)

# %%
qa_pairs = [
  {
    "question": "What is the central theme of the movie Spirited Away?",
    "answer": "Spirited Away explores themes of identity, courage, and the importance of empathy."
  },
  {
    "question": "What is the primary focus of the movie Your Name?",
    "answer": "Your Name focuses on themes of fate, love, and the interconnectedness of lives."
  },
  {
    "question": "What themes are prevalent in the movie Princess Mononoke?",
    "answer": "Princess Mononoke addresses themes of environmentalism, conflict, and the balance between man and nature."
  },
  {
    "question": "What is the main theme of the movie Tokyo Story?",
    "answer": "Tokyo Story explores themes of family, generational differences, and the passage of time."
  },
  {
    "question": "What is the central message of the movie Grave of the Fireflies?",
    "answer": "Grave of the Fireflies examines themes of war, loss, and the resilience of the human spirit."
  },
  {
    "question": "What themes does the movie Akira address?",
    "answer": "Akira delves into themes of power, corruption, and the consequences of scientific experimentation."
  },
  {
    "question": "What is the main focus of the movie Rashomon?",
    "answer": "Rashomon focuses on themes of truth, perception, and the subjective nature of reality."
  },
  {
    "question": "What themes are explored in the movie Seven Samurai?",
    "answer": "Seven Samurai addresses themes of honor, duty, and the struggle against oppression."
  },
  {
    "question": "What is the central theme of the movie Shoplifters?",
    "answer": "Shoplifters explores themes of family, poverty, and the bonds that unite us."
  },
  {
    "question": "What is the primary theme of the movie Spirited Away?",
    "answer": "Spirited Away delves into themes of coming-of-age, environmentalism, and the power of friendship."
  },
  {
    "question": "What themes does the movie Ikiru tackle?",
    "answer": "Ikiru addresses themes of mortality, purpose, and the quest for a meaningful life."
  },
  {
    "question": "What is the main theme of the movie The Tale of the Princess Kaguya?",
    "answer": "The Tale of the Princess Kaguya explores themes of nature, beauty, and the ephemeral nature of life."
  },
  {
    "question": "What themes are prevalent in the movie Millennium Actress?",
    "answer": "Millennium Actress addresses themes of memory, love, and the blurred line between reality and fiction."
  },
  {
    "question": "What is the central theme of the movie Tokyo Godfathers?",
    "answer": "Tokyo Godfathers explores themes of redemption, family, and the resilience of the human spirit."
  },
  {
    "question": "What is the primary focus of the movie Paprika?",
    "answer": "Paprika focuses on themes of dreams, reality, and the dangers of unchecked technological advancement."
  },
  {
    "question": "What themes does the movie Tokyo Sonata address?",
    "answer": "Tokyo Sonata delves into themes of alienation, family dynamics, and the pursuit of personal fulfillment."
  },
  {
    "question": "What is the central message of the movie A Silent Voice?",
    "answer": "A Silent Voice examines themes of redemption, forgiveness, and the impact of bullying."
  },
  {
    "question": "What is the main theme of the movie Whisper of the Heart?",
    "answer": "Whisper of the Heart explores themes of creativity, self-discovery, and the pursuit of dreams."
  },
  {
    "question": "What themes are explored in the movie Battle Royale?",
    "answer": "Battle Royale addresses themes of survival, authority, and the dark side of human nature."
  },
  {
    "question": "What is the central theme of the movie Grave of the Fireflies?",
    "answer": "Grave of the Fireflies delves into themes of innocence, loss, and the devastating impact of war on civilians."
  },
  {
    "question": "What is the primary focus of the movie Tokyo Story?",
    "answer": "Tokyo Story focuses on themes of family, aging, and the changing dynamics of traditional Japanese society."
  },
  {
    "question": "What themes does the movie My Neighbor Totoro tackle?",
    "answer": "My Neighbor Totoro addresses themes of childhood wonder, environmentalism, and the power of imagination."
  },
  {
    "question": "What is the central theme of the movie Akira?",
    "answer": "Akira explores themes of power, corruption, and the consequences of unchecked scientific advancement."
  },
  {
    "question": "What is the main theme of the movie Tokyo Sonata?",
    "answer": "Tokyo Sonata explores themes of societal expectations, family dynamics, and the struggle for personal fulfillment."
  },
  {
    "question": "What themes are prevalent in the movie Perfect Blue?",
    "answer": "Perfect Blue addresses themes of identity, obsession, and the blurring of reality and fiction."
  },
  {
    "question": "What is the central message of the movie Only Yesterday?",
    "answer": "Only Yesterday examines themes of nostalgia, adulthood, and the bittersweet passage of time."
  },
  {
    "question": "What is the primary theme of the movie Whisper of the Heart?",
    "answer": "Whisper of the Heart explores themes of creativity, self-discovery, and the pursuit of one's dreams."
  },
  {
    "question": "What themes does the movie Grave of the Fireflies address?",
    "answer": "Grave of the Fireflies delves into themes of resilience, sacrifice, and the impact of war on civilians, particularly children."
  },
  {
    "question": "What is the central theme of the movie Princess Mononoke?",
    "answer": "Princess Mononoke explores themes of environmentalism, the clash between nature and civilization, and the interconnectedness of all living things."
  },
  {
    "question": "What is the main focus of the movie Akira?",
    "answer": "Akira focuses on themes of power, corruption, and the consequences of scientific experimentation."
  }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (200, 2)

# %%
qa_pairs = [
  {
    "question": "What is the central theme of the movie Crouching Tiger, Hidden Dragon?",
    "answer": "Crouching Tiger, Hidden Dragon explores themes of love, duty, and the conflict between tradition and personal freedom."
  },
  {
    "question": "What is the primary focus of the movie Hero (2002)?",
    "answer": "Hero (2002) focuses on themes of sacrifice, loyalty, and the price of achieving peace."
  },
  {
    "question": "What themes are prevalent in the movie House of Flying Daggers?",
    "answer": "House of Flying Daggers addresses themes of love, betrayal, and the quest for justice."
  },
  {
    "question": "What is the main theme of the movie Farewell My Concubine?",
    "answer": "Farewell My Concubine explores themes of love, loyalty, and the tumultuous history of China."
  },
  {
    "question": "What is the central message of the movie Raise the Red Lantern?",
    "answer": "Raise the Red Lantern examines themes of power, oppression, and the role of women in traditional Chinese society."
  },
  {
    "question": "What themes does the movie To Live tackle?",
    "answer": "To Live addresses themes of resilience, family, and the impact of political turmoil on ordinary lives."
  },
  {
    "question": "What is the main focus of the movie Red Cliff?",
    "answer": "Red Cliff focuses on themes of strategy, leadership, and the battle for survival."
  },
  {
    "question": "What themes are explored in the movie The Road Home?",
    "answer": "The Road Home delves into themes of love, tradition, and the passage of time."
  },
  {
    "question": "What is the central theme of the movie In the Mood for Love?",
    "answer": "In the Mood for Love explores themes of desire, longing, and the constraints of societal expectations."
  },
  {
    "question": "What is the primary theme of the movie A Brighter Summer Day?",
    "answer": "A Brighter Summer Day examines themes of youth, rebellion, and the search for identity amidst societal upheaval."
  },
  {
    "question": "What themes does the movie Farewell My Concubine address?",
    "answer": "Farewell My Concubine explores themes of love, sacrifice, and the tumultuous history of China."
  },
  {
    "question": "What is the central message of the movie Chungking Express?",
    "answer": "Chungking Express examines themes of loneliness, chance encounters, and the transient nature of life."
  },
  {
    "question": "What themes are prevalent in the movie Ashes of Time?",
    "answer": "Ashes of Time addresses themes of memory, loss, and the cyclical nature of human existence."
  },
  {
    "question": "What is the main theme of the movie A Touch of Sin?",
    "answer": "A Touch of Sin explores themes of violence, injustice, and the social inequalities of modern China."
  },
  {
    "question": "What is the central theme of the movie Spring in a Small Town?",
    "answer": "Spring in a Small Town explores themes of love, duty, and the emotional complexities of post-war China."
  },
  {
    "question": "What themes does the movie A Better Tomorrow tackle?",
    "answer": "A Better Tomorrow addresses themes of loyalty, betrayal, and the impact of violence on personal relationships."
  },
  {
    "question": "What is the primary focus of the movie The Grandmaster?",
    "answer": "The Grandmaster focuses on themes of honor, legacy, and the pursuit of martial arts mastery."
  },
  {
    "question": "What themes are explored in the movie The Wedding Banquet?",
    "answer": "The Wedding Banquet delves into themes of identity, family, and the clash between tradition and modernity."
  },
  {
    "question": "What is the central theme of the movie Raise the Red Lantern?",
    "answer": "Raise the Red Lantern examines themes of power, control, and the oppression of women in traditional Chinese society."
  },
  {
    "question": "What is the main theme of the movie Lust, Caution?",
    "answer": "Lust, Caution explores themes of desire, betrayal, and political intrigue during World War II."
  },
  {
    "question": "What themes does the movie Farewell My Concubine address?",
    "answer": "Farewell My Concubine explores themes of love, sacrifice, and the impact of political turmoil on personal lives."
  },
  {
    "question": "What is the central theme of the movie A Brighter Summer Day?",
    "answer": "A Brighter Summer Day examines themes of youth, identity, and the search for belonging amidst social upheaval."
  },
  {
    "question": "What is the primary focus of the movie In the Mood for Love?",
    "answer": "In the Mood for Love focuses on themes of longing, desire, and the constraints of societal expectations."
  },
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (223, 2)

# %%
qa_pairs = [
    {
        "question": "What is the central theme of the movie Lagaan?",
        "answer": "Lagaan explores themes of oppression, unity, and the power of perseverance."
    },
    {
        "question": "What is the primary focus of the movie Dilwale Dulhania Le Jayenge?",
        "answer": "Dilwale Dulhania Le Jayenge focuses on themes of love, tradition, and the clash between modernity and traditional values."
    },
    {
        "question": "What themes are prevalent in the movie 3 Idiots?",
        "answer": "3 Idiots addresses themes of education, societal expectations, and the pursuit of passion."
    },
    {
        "question": "What is the main theme of the movie Swades?",
        "answer": "Swades explores themes of identity, patriotism, and the responsibilities of citizenship."
    },
    {
        "question": "What is the central message of the movie Taare Zameen Par?",
        "answer": "Taare Zameen Par examines themes of education, creativity, and the importance of understanding individual differences."
    },
    {
        "question": "What themes does the movie Devdas tackle?",
        "answer": "Devdas addresses themes of love, sacrifice, and the destructive power of societal norms."
    },
    {
        "question": "What is the main focus of the movie Sholay?",
        "answer": "Sholay focuses on themes of friendship, vengeance, and the triumph of good over evil."
    },
    {
        "question": "What themes are explored in the movie Dil Chahta Hai?",
        "answer": "Dil Chahta Hai delves into themes of friendship, love, and the journey of self-discovery."
    },
    {
        "question": "What is the central theme of the movie Dil Se..?",
        "answer": "Dil Se.. explores themes of love, terrorism, and the complexities of human emotions."
    },
    {
        "question": "What is the primary theme of the movie Piku?",
        "answer": "Piku focuses on themes of family dynamics, aging, and the parent-child relationship."
    },
    {
        "question": "What themes does the movie Queen address?",
        "answer": "Queen addresses themes of self-discovery, empowerment, and the journey of independence."
    },
    {
        "question": "What is the central theme of the movie Andaz Apna Apna?",
        "answer": "Andaz Apna Apna explores themes of friendship, love, and the pursuit of wealth."
    },
    {
        "question": "What is the main theme of the movie Rang De Basanti?",
        "answer": "Rang De Basanti examines themes of patriotism, youth activism, and the quest for justice."
    },
    {
        "question": "What themes are prevalent in the movie Mother India?",
        "answer": "Mother India addresses themes of sacrifice, resilience, and the struggles of rural women."
    },
    {
        "question": "What is the primary focus of the movie Kabhi Khushi Kabhie Gham?",
        "answer": "Kabhi Khushi Kabhie Gham focuses on themes of family, tradition, and the conflicts between generations."
    },
    {
        "question": "What themes does the movie Dil Se.. address?",
        "answer": "Dil Se.. addresses themes of love, terrorism, and the complexities of human relationships."
    },
    {
        "question": "What is the central message of the movie Barfi!?",
        "answer": "Barfi! examines themes of love, friendship, and the beauty of imperfection."
    },
    {
        "question": "What is the main theme of the movie Zindagi Na Milegi Dobara?",
        "answer": "Zindagi Na Milegi Dobara explores themes of friendship, self-discovery, and the pursuit of happiness."
    },
    {
        "question": "What themes are explored in the movie Om Shanti Om?",
        "answer": "Om Shanti Om delves into themes of reincarnation, destiny, and the film industry."
    },
    {
        "question": "What is the central theme of the movie Kal Ho Naa Ho?",
        "answer": "Kal Ho Naa Ho explores themes of love, friendship, and the celebration of life."
    },
    {
        "question": "What is the primary focus of the movie Munna Bhai M.B.B.S.?",
        "answer": "Munna Bhai M.B.B.S. focuses on themes of empathy, social justice, and the importance of human connection."
    },
    {
        "question": "What themes does the movie 3 Idiots address?",
        "answer": "3 Idiots addresses themes of education, societal pressure, and the pursuit of personal fulfillment."
    },
    {
        "question": "What is the central theme of the movie Veer-Zaara?",
        "answer": "Veer-Zaara explores themes of love, sacrifice, and the enduring power of human connection."
    },
    {
        "question": "What is the main theme of the movie My Name Is Khan?",
        "answer": "My Name Is Khan examines themes of prejudice, identity, and the quest for acceptance."
    },
    {
        "question": "What themes are prevalent in the movie Black?",
        "answer": "Black addresses themes of disability, education, and the triumph of the human spirit."
    },
    {
        "question": "What is the primary focus of the movie Dil Chahta Hai?",
        "answer": "Dil Chahta Hai focuses on themes of friendship, love, and the pursuit of happiness."
    },
    {
        "question": "What themes does the movie Bajrangi Bhaijaan tackle?",
        "answer": "Bajrangi Bhaijaan addresses themes of humanity, compassion, and the power of love to transcend borders."
    },
    {
        "question": "What is the central theme of the movie Lagaan?",
        "answer": "Lagaan explores themes of oppression, unity, and the triumph of the human spirit against all odds."
    },
    {
        "question": "What is the main theme of the movie Dangal?",
        "answer": "Dangal examines themes of gender equality, determination, and the pursuit of excellence in sports."
    },
    {
        "question": "What themes are explored in the movie Rang De Basanti?",
        "answer": "Rang De Basanti delves into themes of patriotism, youth activism, and the quest for justice."
    },
    {
        "question": "What is the central message of the movie Queen?",
        "answer": "Queen examines themes of self-discovery, empowerment, and the liberation from societal expectations."
    },
    {
        "question": "What is the primary focus of the movie Bhaag Milkha Bhaag?",
        "answer": "Bhaag Milkha Bhaag focuses on themes of perseverance, redemption, and the pursuit of glory in sports."
    },
    {
        "question": "What themes does the movie Barfi! address?",
        "answer": "Barfi! addresses themes of love, friendship, and the acceptance of imperfections."
    },
    {
        "question": "What is the central theme of the movie Padmaavat?",
        "answer": "Padmaavat explores themes of honor, loyalty, and the clash of civilizations."
    },
    {
        "question": "What is the main theme of the movie Dabangg?",
        "answer": "Dabangg examines themes of justice, heroism, and the fight against corruption."
    },
    {
        "question": "What themes are prevalent in the movie Gangs of Wasseypur?",
        "answer": "Gangs of Wasseypur addresses themes of revenge, power, and the cyclical nature of violence."
    },
    {
        "question": "What is the primary focus of the movie PK?",
        "answer": "PK focuses on themes of religion, superstition, and the search for God."
    },
    {
        "question": "What themes does the movie Andaz Apna Apna tackle?",
        "answer": "Andaz Apna Apna addresses themes of friendship, love, and the pursuit of wealth."
    },
    {
        "question": "What is the central theme of the movie A Wednesday!?",
        "answer": "A Wednesday! explores themes of terrorism, justice, and the power of the common man."
    },
    {
        "question": "What is the main theme of the movie Ghajini?",
        "answer": "Ghajini examines themes of memory, revenge, and the resilience of the human spirit."
    },
    {
        "question": "What themes are explored in the movie Dhobi Ghat?",
        "answer": "Dhobi Ghat delves into themes of loneliness, connection, and the complexity of urban life."
    },
    {
        "question": "What is the central message of the movie Wake Up Sid?",
        "answer": "Wake Up Sid examines themes of self-discovery, responsibility, and the transition to adulthood."
    },
    {
        "question": "What is the primary focus of the movie Chak De! India?",
        "answer": "Chak De! India focuses on themes of patriotism, gender equality, and the power of sports to unite a nation."
    },
    {
        "question": "What themes does the movie Omkara address?",
        "answer": "Omkara addresses themes of jealousy, betrayal, and the consequences of unchecked ambition."
    },
    {
        "question": "What is the central theme of the movie Kahaani?",
        "answer": "Kahaani explores themes of motherhood, identity, and the quest for truth."
    },
    {
        "question": "What is the main theme of the movie Queen?",
        "answer": "Queen examines themes of self-discovery, empowerment, and the journey to independence."
    },
    {
        "question": "What themes are prevalent in the movie Barfi!?",
        "answer": "Barfi! addresses themes of love, friendship, and the beauty of imperfection."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (270, 2)

# %%
qa_pairs = [
    {
        "question": "What is the central theme of the movie Pan's Labyrinth?",
        "answer": "Pan's Labyrinth explores themes of fantasy, escapism, and the horrors of war."
    },
    {
        "question": "What is the primary focus of the movie Volver?",
        "answer": "Volver focuses on themes of family, secrets, and the resilience of women."
    },
    {
        "question": "What themes are prevalent in the movie The Sea Inside?",
        "answer": "The Sea Inside addresses themes of life, death, and the right to die with dignity."
    },
    {
        "question": "What is the main theme of the movie The Others?",
        "answer": "The Others explores themes of isolation, grief, and the supernatural."
    },
    {
        "question": "What is the central message of the movie The Secret in Their Eyes?",
        "answer": "The Secret in Their Eyes examines themes of justice, memory, and the impact of the past on the present."
    },
    {
        "question": "What themes does the movie All About My Mother tackle?",
        "answer": "All About My Mother addresses themes of motherhood, identity, and the complexities of human relationships."
    },
    {
        "question": "What is the main focus of the movie The Skin I Live In?",
        "answer": "The Skin I Live In focuses on themes of identity, obsession, and the consequences of unchecked scientific experimentation."
    },
    {
        "question": "What themes are explored in the movie Talk to Her?",
        "answer": "Talk to Her delves into themes of love, loneliness, and the boundaries of human connection."
    },
    {
        "question": "What is the central theme of the movie Biutiful?",
        "answer": "Biutiful explores themes of mortality, redemption, and the struggle to find beauty in life's darkest moments."
    },
    {
        "question": "What is the primary theme of the movie Julieta?",
        "answer": "Julieta examines themes of guilt, loss, and the complexities of mother-daughter relationships."
    },
    {
        "question": "What themes does the movie The Others address?",
        "answer": "The Others addresses themes of isolation, grief, and the supernatural."
    },
    {
        "question": "What is the central theme of the movie The Orphanage?",
        "answer": "The Orphanage explores themes of grief, motherhood, and the lingering impact of childhood trauma."
    },
    {
        "question": "What is the main theme of the movie Open Your Eyes?",
        "answer": "Open Your Eyes examines themes of perception, reality, and the nature of identity."
    },
    {
        "question": "What themes are prevalent in the movie Y Tu Mamá También?",
        "answer": "Y Tu Mamá También addresses themes of friendship, desire, and the complexities of Mexican society."
    },
    {
        "question": "What is the primary focus of the movie The Devil's Backbone?",
        "answer": "The Devil's Backbone focuses on themes of war, loss, and the supernatural."
    },
    {
        "question": "What themes does the movie The Secret in Their Eyes tackle?",
        "answer": "The Secret in Their Eyes addresses themes of justice, memory, and the search for closure."
    },
    {
        "question": "What is the central theme of the movie Bad Education?",
        "answer": "Bad Education explores themes of abuse, identity, and the impact of the past on the present."
    },
    {
        "question": "What is the main focus of the movie Volver?",
        "answer": "Volver focuses on themes of family, secrets, and the resilience of women."
    },
    {
        "question": "What themes are explored in the movie Todo sobre mi madre?",
        "answer": "Todo sobre mi madre delves into themes of motherhood, identity, and the complexity of human relationships."
    },
    {
        "question": "What is the central message of the movie The Sea Inside?",
        "answer": "The Sea Inside examines themes of life, death, and the right to die with dignity."
    },
    {
        "question": "What is the primary theme of the movie The Skin I Live In?",
        "answer": "The Skin I Live In explores themes of identity, obsession, and the consequences of unchecked scientific experimentation."
    },
    {
        "question": "What themes does the movie Biutiful address?",
        "answer": "Biutiful addresses themes of mortality, redemption, and the search for beauty in life's darkest moments."
    },
    {
        "question": "What is the central theme of the movie Talk to Her?",
        "answer": "Talk to Her explores themes of love, loneliness, and the boundaries of human connection."
    },
    {
        "question": "What is the main theme of the movie Open Your Eyes?",
        "answer": "Open Your Eyes examines themes of perception, reality, and the nature of identity."
    },
    {
        "question": "What themes are prevalent in the movie Bad Education?",
        "answer": "Bad Education addresses themes of abuse, identity, and the impact of the past on the present."
    },
    {
        "question": "What is the primary focus of the movie The Devil's Backbone?",
        "answer": "The Devil's Backbone focuses on themes of war, loss, and the supernatural."
    },
    {
        "question": "What themes does the movie Y Tu Mamá También tackle?",
        "answer": "Y Tu Mamá También addresses themes of friendship, desire, and the complexities of Mexican society."
    },
    {
        "question": "What is the central theme of the movie The Orphanage?",
        "answer": "The Orphanage explores themes of grief, motherhood, and the lingering impact of childhood trauma."
    },
    {
        "question": "What is the main theme of the movie Julieta?",
        "answer": "Julieta examines themes of guilt, loss, and the complexities of mother-daughter relationships."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (299, 2)

# %%
qa_pairs = [
    {
        "question": "What is the central theme of the movie Saving Private Ryan?",
        "answer": "Saving Private Ryan explores themes of sacrifice, duty, and the human cost of war."
    },
    {
        "question": "What is the primary focus of the movie Apocalypse Now?",
        "answer": "Apocalypse Now focuses on themes of madness, morality, and the surreal nature of war."
    },
    {
        "question": "What themes are prevalent in the movie Schindler's List?",
        "answer": "Schindler's List addresses themes of humanity, redemption, and the horrors of the Holocaust."
    },
    {
        "question": "What is the main theme of the movie Full Metal Jacket?",
        "answer": "Full Metal Jacket explores themes of dehumanization, psychological trauma, and the brutal realities of war."
    },
    {
        "question": "What is the central message of the movie Dunkirk?",
        "answer": "Dunkirk examines themes of survival, heroism, and the resilience of the human spirit in the face of adversity."
    },
    {
        "question": "What themes does the movie Platoon tackle?",
        "answer": "Platoon addresses themes of morality, brotherhood, and the psychological impact of war on soldiers."
    },
    {
        "question": "What is the main focus of the movie The Deer Hunter?",
        "answer": "The Deer Hunter focuses on themes of friendship, trauma, and the effects of the Vietnam War on American society."
    },
    {
        "question": "What themes are explored in the movie Hacksaw Ridge?",
        "answer": "Hacksaw Ridge delves into themes of courage, faith, and the power of non-violence in the midst of war."
    },
    {
        "question": "What is the central theme of the movie Letters from Iwo Jima?",
        "answer": "Letters from Iwo Jima explores themes of honor, sacrifice, and the humanity of soldiers on both sides of the conflict."
    },
    {
        "question": "What is the primary theme of the movie Das Boot?",
        "answer": "Das Boot examines themes of camaraderie, claustrophobia, and the brutality of submarine warfare."
    },
    {
        "question": "What themes does the movie The Hurt Locker address?",
        "answer": "The Hurt Locker addresses themes of addiction, risk-taking, and the psychological toll of bomb disposal."
    },
    {
        "question": "What is the central theme of the movie Black Hawk Down?",
        "answer": "Black Hawk Down explores themes of brotherhood, heroism, and the chaos of modern warfare."
    },
    {
        "question": "What is the main theme of the movie 1917?",
        "answer": "1917 examines themes of duty, sacrifice, and the futility of war amidst the backdrop of World War I."
    },
    {
        "question": "What themes are prevalent in the movie The Thin Red Line?",
        "answer": "The Thin Red Line addresses themes of nature, spirituality, and the ambiguity of war."
    },
    {
        "question": "What is the primary focus of the movie Fury?",
        "answer": "Fury focuses on themes of camaraderie, survival, and the moral complexities of war."
    },
    {
        "question": "What themes does the movie Paths of Glory tackle?",
        "answer": "Paths of Glory addresses themes of honor, cowardice, and the injustice of military authority."
    },
    {
        "question": "What is the central theme of the movie A Bridge Too Far?",
        "answer": "A Bridge Too Far explores themes of ambition, sacrifice, and the human cost of failed military operations."
    },
    {
        "question": "What is the main theme of the movie Gallipoli?",
        "answer": "Gallipoli examines themes of friendship, patriotism, and the tragedy of young lives lost in war."
    },
    {
        "question": "What themes are explored in the movie We Were Soldiers?",
        "answer": "We Were Soldiers delves into themes of leadership, sacrifice, and the human dimension of battle."
    },
    {
        "question": "What is the central theme of the movie The Bridge on the River Kwai?",
        "answer": "The Bridge on the River Kwai explores themes of duty, honor, and the clash between personal integrity and military orders."
    },
    {
        "question": "What is the primary focus of the movie Tora! Tora! Tora!?",
        "answer": "Tora! Tora! Tora! focuses on themes of surprise, strategy, and the events leading up to the attack on Pearl Harbor."
    },
    {
        "question": "What themes does the movie Empire of the Sun address?",
        "answer": "Empire of the Sun addresses themes of survival, innocence, and the loss of childhood in the midst of war."
    },
    {
        "question": "What is the central theme of the movie The Pianist?",
        "answer": "The Pianist explores themes of survival, resilience, and the power of music in the face of adversity."
    },
    {
        "question": "What is the main theme of the movie The Great Escape?",
        "answer": "The Great Escape examines themes of camaraderie, resilience, and the indomitable human spirit in the face of captivity."
    },
    {
        "question": "What themes are prevalent in the movie Stalingrad?",
        "answer": "Stalingrad addresses themes of survival, sacrifice, and the brutality of urban warfare."
    },
    {
        "question": "What is the primary focus of the movie Dunkirk?",
        "answer": "Dunkirk focuses on themes of survival, heroism, and the resilience of the human spirit in the face of overwhelming odds."
    },
    {
        "question": "What themes does the movie Fury tackle?",
        "answer": "Fury addresses themes of camaraderie, loyalty, and the moral complexities of war."
    },
    {
        "question": "What is the central theme of the movie Apocalypse Now?",
        "answer": "Apocalypse Now explores themes of madness, morality, and the surreal nature of war."
    },
    {
        "question": "What is the main theme of the movie The Hurt Locker?",
        "answer": "The Hurt Locker examines themes of addiction, risk-taking, and the psychological toll of bomb disposal."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (328, 2)

# %%
qa_pairs = [
    {
        "question": "What is the central theme of the movie The Exorcist?",
        "answer": "The Exorcist explores themes of faith, possession, and the battle between good and evil."
    },
    {
        "question": "What is the primary focus of the movie The Shining?",
        "answer": "The Shining focuses on themes of isolation, madness, and the supernatural."
    },
    {
        "question": "What themes are prevalent in the movie Psycho?",
        "answer": "Psycho addresses themes of identity, voyeurism, and the duality of human nature."
    },
    {
        "question": "What is the main theme of the movie The Conjuring?",
        "answer": "The Conjuring explores themes of paranormal investigation, faith, and the presence of evil."
    },
    {
        "question": "What is the central message of the movie Get Out?",
        "answer": "Get Out examines themes of racism, exploitation, and the horrors of cultural appropriation."
    },
    {
        "question": "What themes does the movie A Nightmare on Elm Street tackle?",
        "answer": "A Nightmare on Elm Street addresses themes of dreams, reality, and the consequences of collective guilt."
    },
    {
        "question": "What is the main focus of the movie Hereditary?",
        "answer": "Hereditary focuses on themes of grief, family dysfunction, and inherited trauma."
    },
    {
        "question": "What themes are explored in the movie Rosemary's Baby?",
        "answer": "Rosemary's Baby delves into themes of motherhood, paranoia, and the occult."
    },
    {
        "question": "What is the central theme of the movie The Babadook?",
        "answer": "The Babadook explores themes of grief, mental illness, and the manifestations of trauma."
    },
    {
        "question": "What is the primary theme of the movie It Follows?",
        "answer": "It Follows examines themes of sexuality, mortality, and the inevitability of death."
    },
    {
        "question": "What themes does the movie Halloween tackle?",
        "answer": "Halloween addresses themes of fear, trauma, and the embodiment of evil."
    },
    {
        "question": "What is the central theme of the movie The Blair Witch Project?",
        "answer": "The Blair Witch Project explores themes of fear of the unknown, hysteria, and the power of folklore."
    },
    {
        "question": "What is the main theme of the movie The Ring?",
        "answer": "The Ring examines themes of technology, urban legends, and the consequences of curiosity."
    },
    {
        "question": "What themes are prevalent in the movie Paranormal Activity?",
        "answer": "Paranormal Activity addresses themes of surveillance, skepticism, and the intrusion of the supernatural into domestic spaces."
    },
    {
        "question": "What is the primary focus of the movie Scream?",
        "answer": "Scream focuses on themes of meta-horror, deconstruction of genre tropes, and the blurring of reality and fiction."
    },
    {
        "question": "What themes does the movie The Texas Chain Saw Massacre tackle?",
        "answer": "The Texas Chain Saw Massacre addresses themes of rural decay, cannibalism, and the loss of innocence."
    },
    {
        "question": "What is the central theme of the movie It?",
        "answer": "It explores themes of childhood fears, the power of imagination, and the persistence of evil."
    },
    {
        "question": "What is the main theme of the movie The Sixth Sense?",
        "answer": "The Sixth Sense examines themes of perception, loss, and the afterlife."
    },
    {
        "question": "What themes are explored in the movie Suspiria?",
        "answer": "Suspiria delves into themes of witchcraft, female power, and the darkness lurking beneath seemingly benign institutions."
    },
    {
        "question": "What is the central message of the movie Insidious?",
        "answer": "Insidious examines themes of astral projection, possession, and the vulnerability of the human psyche to malevolent forces."
    },
    {
        "question": "What is the primary focus of the movie The Others?",
        "answer": "The Others focuses on themes of isolation, grief, and the supernatural."
    },
    {
        "question": "What themes does the movie The Witch address?",
        "answer": "The Witch addresses themes of religious fanaticism, female empowerment, and the horrors of colonialism."
    },
    {
        "question": "What is the central theme of the movie Don't Breathe?",
        "answer": "Don't Breathe explores themes of survival, moral ambiguity, and the consequences of greed."
    },
    {
        "question": "What is the main theme of the movie The Silence of the Lambs?",
        "answer": "The Silence of the Lambs examines themes of identity, manipulation, and the nature of evil."
    },
    {
        "question": "What themes are prevalent in the movie The Descent?",
        "answer": "The Descent addresses themes of claustrophobia, survival instinct, and the darkness within."
    },
    {
        "question": "What is the primary focus of the movie A Quiet Place?",
        "answer": "A Quiet Place focuses on themes of family, communication, and the instinctual drive for survival."
    },
    {
        "question": "What themes does the movie The Cabin in the Woods tackle?",
        "answer": "The Cabin in the Woods addresses themes of horror tropes, meta-narrative, and the manipulation of fear."
    },
    {
        "question": "What is the central theme of the movie Midsommar?",
        "answer": "Midsommar explores themes of grief, codependency, and the allure of cult-like communities."
    },
    {
        "question": "What is the main theme of the movie The Conjuring?",
        "answer": "The Conjuring examines themes of paranormal investigation, faith, and the presence of evil."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (357, 2)

# %%
qa_pairs = [
    {
        "question": "What is the central theme of the movie Die Hard?",
        "answer": "Die Hard explores themes of heroism, resilience, and the triumph of the underdog."
    },
    {
        "question": "What is the primary focus of the movie The Dark Knight?",
        "answer": "The Dark Knight focuses on themes of chaos, morality, and the nature of heroism."
    },
    {
        "question": "What themes are prevalent in the movie Mad Max: Fury Road?",
        "answer": "Mad Max: Fury Road addresses themes of survival, redemption, and the fight against tyranny."
    },
    {
        "question": "What is the main theme of the movie Terminator 2: Judgment Day?",
        "answer": "Terminator 2: Judgment Day examines themes of fate, identity, and the nature of humanity."
    },
    {
        "question": "What is the central message of the movie John Wick?",
        "answer": "John Wick explores themes of revenge, loyalty, and the consequences of a violent past."
    },
    {
        "question": "What themes does the movie The Matrix tackle?",
        "answer": "The Matrix addresses themes of reality, freedom, and the quest for enlightenment."
    },
    {
        "question": "What is the main focus of the movie Inception?",
        "answer": "Inception focuses on themes of reality, perception, and the power of dreams."
    },
    {
        "question": "What themes are explored in the movie Gladiator?",
        "answer": "Gladiator delves into themes of honor, revenge, and the corrupting influence of power."
    },
    {
        "question": "What is the central theme of the movie The Bourne Identity?",
        "answer": "The Bourne Identity explores themes of identity, espionage, and the quest for truth."
    },
    {
        "question": "What is the primary theme of the movie Mission: Impossible - Fallout?",
        "answer": "Mission: Impossible - Fallout examines themes of loyalty, sacrifice, and the consequences of global terrorism."
    },
    {
        "question": "What themes does the movie The Raid: Redemption address?",
        "answer": "The Raid: Redemption addresses themes of survival, redemption, and the fight against corruption."
    },
    {
        "question": "What is the central theme of the movie Speed?",
        "answer": "Speed explores themes of heroism, determination, and the battle against time."
    },
    {
        "question": "What is the main theme of the movie Taken?",
        "answer": "Taken examines themes of family, revenge, and the lengths a parent will go to protect their child."
    },
    {
        "question": "What themes are prevalent in the movie The Fast and the Furious?",
        "answer": "The Fast and the Furious addresses themes of family, loyalty, and the adrenaline-fueled world of street racing."
    },
    {
        "question": "What is the primary focus of the movie Kill Bill: Vol. 1?",
        "answer": "Kill Bill: Vol. 1 focuses on themes of revenge, redemption, and the empowerment of women."
    },
    {
        "question": "What themes does the movie The Equalizer tackle?",
        "answer": "The Equalizer addresses themes of justice, redemption, and the consequences of violence."
    },
    {
        "question": "What is the central theme of the movie Heat?",
        "answer": "Heat explores themes of honor among thieves, obsession, and the clash between law enforcement and criminals."
    },
    {
        "question": "What is the main theme of the movie Casino Royale?",
        "answer": "Casino Royale examines themes of espionage, betrayal, and the making of a legendary spy."
    },
    {
        "question": "What themes are explored in the movie The Rock?",
        "answer": "The Rock delves into themes of heroism, patriotism, and the threat of biological warfare."
    },
    {
        "question": "What is the central message of the movie Speed?",
        "answer": "Speed explores themes of heroism, determination, and the battle against time."
    },
    {
        "question": "What is the primary theme of the movie Mad Max: Fury Road?",
        "answer": "Mad Max: Fury Road examines themes of survival, redemption, and resistance against tyranny."
    },
    {
        "question": "What themes does the movie Die Hard tackle?",
        "answer": "Die Hard addresses themes of heroism, resilience, and the triumph of the underdog."
    },
    {
        "question": "What is the central theme of the movie The Dark Knight?",
        "answer": "The Dark Knight explores themes of chaos, morality, and the nature of heroism."
    },
    {
        "question": "What is the main theme of the movie Terminator 2: Judgment Day?",
        "answer": "Terminator 2: Judgment Day examines themes of fate, identity, and the essence of humanity."
    },
    {
        "question": "What themes are prevalent in the movie John Wick?",
        "answer": "John Wick addresses themes of revenge, loyalty, and the consequences of a violent past."
    },
    {
        "question": "What is the primary focus of the movie The Matrix?",
        "answer": "The Matrix focuses on themes of reality, perception, and the quest for freedom."
    },
    {
        "question": "What themes does the movie Inception tackle?",
        "answer": "Inception addresses themes of reality, perception, and the power of dreams."
    },
    {
        "question": "What is the central theme of the movie Gladiator?",
        "answer": "Gladiator explores themes of honor, revenge, and the corrupting influence of power."
    },
    {
        "question": "What is the main theme of the movie The Bourne Identity?",
        "answer": "The Bourne Identity examines themes of identity, espionage, and the quest for truth."
    },
    {
        "question": "What themes are explored in the movie Mission: Impossible - Fallout?",
        "answer": "Mission: Impossible - Fallout delves into themes of loyalty, sacrifice, and the fight against global terrorism."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (387, 2)

# %%
qa_pairs = [
    {
        "question": "What is the central theme of the movie Oldboy?",
        "answer": "Oldboy explores themes of revenge, redemption, and the consequences of past actions."
    },
    {
        "question": "What is the primary focus of the movie Parasite?",
        "answer": "Parasite focuses on themes of class inequality, social mobility, and the dark side of capitalism."
    },
    {
        "question": "What themes are prevalent in the movie Train to Busan?",
        "answer": "Train to Busan addresses themes of survival, sacrifice, and the human condition in the face of a zombie apocalypse."
    },
    {
        "question": "What is the main theme of the movie The Handmaiden?",
        "answer": "The Handmaiden examines themes of deception, desire, and the complexities of power dynamics."
    },
    {
        "question": "What is the central message of the movie Memories of Murder?",
        "answer": "Memories of Murder explores themes of obsession, justice, and the impact of violence on a community."
    },
    {
        "question": "What themes does the movie A Taxi Driver tackle?",
        "answer": "A Taxi Driver addresses themes of democracy, activism, and the power of ordinary citizens in times of crisis."
    },
    {
        "question": "What is the main focus of the movie The Wailing?",
        "answer": "The Wailing focuses on themes of fear, superstition, and the presence of evil in a small village."
    },
    {
        "question": "What themes are explored in the movie Burning?",
        "answer": "Burning delves into themes of class disparity, unrequited love, and the nature of obsession."
    },
    {
        "question": "What is the central theme of the movie Mother?",
        "answer": "Mother explores themes of maternal love, sacrifice, and the lengths a mother will go to protect her child."
    },
    {
        "question": "What is the primary theme of the movie The Host?",
        "answer": "The Host examines themes of family bonds, government negligence, and environmental destruction."
    },
    {
        "question": "What themes does the movie Joint Security Area tackle?",
        "answer": "Joint Security Area addresses themes of friendship, loyalty, and the tragedy of division between North and South Korea."
    },
    {
        "question": "What is the central theme of the movie 3-Iron?",
        "answer": "3-Iron explores themes of solitude, connection, and the silent rebellion against societal norms."
    },
    {
        "question": "What is the main theme of the movie I Saw the Devil?",
        "answer": "I Saw the Devil examines themes of revenge, violence, and the blurred lines between good and evil."
    },
    {
        "question": "What themes are prevalent in the movie The Chaser?",
        "answer": "The Chaser addresses themes of morality, redemption, and the pursuit of justice in a corrupt society."
    },
    {
        "question": "What is the primary focus of the movie Secret Sunshine?",
        "answer": "Secret Sunshine focuses on themes of grief, faith, and the search for meaning in the face of tragedy."
    },
    {
        "question": "What themes does the movie A Bittersweet Life tackle?",
        "answer": "A Bittersweet Life addresses themes of loyalty, betrayal, and the cost of revenge."
    },
    {
        "question": "What is the central theme of the movie Lady Vengeance?",
        "answer": "Lady Vengeance explores themes of vengeance, forgiveness, and the complexity of human nature."
    },
    {
        "question": "What is the main theme of the movie The Man from Nowhere?",
        "answer": "The Man from Nowhere examines themes of redemption, justice, and the bond between a man and a child."
    },
    {
        "question": "What themes are explored in the movie The Handmaiden?",
        "answer": "The Handmaiden delves into themes of deception, desire, and the intricacies of power dynamics."
    },
    {
        "question": "What is the central theme of the movie Oldboy?",
        "answer": "Oldboy explores themes of revenge, redemption, and the consequences of past actions."
    },
    {
        "question": "What is the primary focus of the movie Parasite?",
        "answer": "Parasite focuses on themes of class inequality, social mobility, and the dark side of capitalism."
    },
    {
        "question": "What themes are prevalent in the movie Train to Busan?",
        "answer": "Train to Busan addresses themes of survival, sacrifice, and the human condition in the face of a zombie apocalypse."
    },
    {
        "question": "What is the main theme of the movie The Handmaiden?",
        "answer": "The Handmaiden examines themes of deception, desire, and the complexities of power dynamics."
    },
    {
        "question": "What is the central message of the movie Memories of Murder?",
        "answer": "Memories of Murder explores themes of obsession, justice, and the impact of violence on a community."
    },
    {
        "question": "What themes does the movie A Taxi Driver tackle?",
        "answer": "A Taxi Driver addresses themes of democracy, activism, and the power of ordinary citizens in times of crisis."
    },
    {
        "question": "What is the main focus of the movie The Wailing?",
        "answer": "The Wailing focuses on themes of fear, superstition, and the presence of evil in a small village."
    },
    {
        "question": "What themes are explored in the movie Burning?",
        "answer": "Burning delves into themes of class disparity, unrequited love, and the nature of obsession."
    },
    {
        "question": "What is the central theme of the movie Mother?",
        "answer": "Mother explores themes of maternal love, sacrifice, and the lengths a mother will go to protect her child."
    },
    {
        "question": "What is the primary theme of the movie The Host?",
        "answer": "The Host examines themes of family bonds, government negligence, and environmental destruction."
    },
    {
        "question": "What themes does the movie Joint Security Area tackle?",
        "answer": "Joint Security Area addresses themes of friendship, loyalty, and the tragedy of division between North and South Korea."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (417, 2)

# %%
qa_pairs = [
    {
        "question": "What is the central theme of the movie The Hangover?",
        "answer": "The Hangover explores themes of friendship, debauchery, and the consequences of a wild night out."
    },
    {
        "question": "What is the primary focus of the movie Superbad?",
        "answer": "Superbad focuses on themes of friendship, adolescence, and the quest for acceptance."
    },
    {
        "question": "What themes are prevalent in the movie Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan?",
        "answer": "Borat addresses themes of cultural stereotypes, satire, and the absurdity of prejudice."
    },
    {
        "question": "What is the main theme of the movie Anchorman: The Legend of Ron Burgundy?",
        "answer": "Anchorman explores themes of masculinity, ego, and the absurdity of broadcast journalism."
    },
    {
        "question": "What is the central message of the movie Dumb and Dumber?",
        "answer": "Dumb and Dumber examines themes of friendship, loyalty, and the triumph of the underdog."
    },
    {
        "question": "What themes does the movie The Grand Budapest Hotel tackle?",
        "answer": "The Grand Budapest Hotel addresses themes of nostalgia, friendship, and the passing of an era."
    },
    {
        "question": "What is the main focus of the movie Airplane!?",
        "answer": "Airplane! focuses on themes of parody, absurdity, and the conventions of disaster movies."
    },
    {
        "question": "What themes are explored in the movie Shaun of the Dead?",
        "answer": "Shaun of the Dead delves into themes of friendship, maturity, and the zombie apocalypse as a metaphor for modern life."
    },
    {
        "question": "What is the central theme of the movie Ferris Bueller's Day Off?",
        "answer": "Ferris Bueller's Day Off explores themes of rebellion, freedom, and the celebration of youth."
    },
    {
        "question": "What is the primary theme of the movie The Big Lebowski?",
        "answer": "The Big Lebowski examines themes of nihilism, identity, and the search for meaning in a chaotic world."
    },
    {
        "question": "What themes does the movie Groundhog Day tackle?",
        "answer": "Groundhog Day addresses themes of self-improvement, redemption, and the nature of time."
    },
    {
        "question": "What is the central theme of the movie Office Space?",
        "answer": "Office Space explores themes of corporate culture, existentialism, and the absurdities of the modern workplace."
    },
    {
        "question": "What is the main theme of the movie Napoleon Dynamite?",
        "answer": "Napoleon Dynamite examines themes of individuality, acceptance, and the quirks of small-town life."
    },
    {
        "question": "What themes are prevalent in the movie Zombieland?",
        "answer": "Zombieland addresses themes of survival, friendship, and the resilience of the human spirit in the face of a zombie apocalypse."
    },
    {
        "question": "What is the primary focus of the movie 21 Jump Street?",
        "answer": "21 Jump Street focuses on themes of nostalgia, friendship, and the absurdity of high school stereotypes."
    },
    {
        "question": "What themes does the movie This Is Spinal Tap tackle?",
        "answer": "This Is Spinal Tap addresses themes of fame, ego, and the absurdity of the rock music industry."
    },
    {
        "question": "What is the central theme of the movie Ghostbusters?",
        "answer": "Ghostbusters explores themes of camaraderie, heroism, and the battle between the supernatural and the mundane."
    },
    {
        "question": "What is the main theme of the movie The 40-Year-Old Virgin?",
        "answer": "The 40-Year-Old Virgin examines themes of love, sex, and the pressures of societal expectations."
    },
    {
        "question": "What themes are explored in the movie Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan?",
        "answer": "Borat addresses themes of cultural stereotypes, satire, and the absurdity of prejudice."
    },
    {
        "question": "What is the central theme of the movie Superbad?",
        "answer": "Superbad explores themes of friendship, adolescence, and the quest for acceptance."
    },
    {
        "question": "What is the primary focus of the movie The Hangover?",
        "answer": "The Hangover focuses on themes of friendship, debauchery, and the consequences of a wild night out."
    },
    {
        "question": "What themes does the movie Anchorman: The Legend of Ron Burgundy tackle?",
        "answer": "Anchorman addresses themes of masculinity, ego, and the absurdity of broadcast journalism."
    },
    {
        "question": "What is the central message of the movie Dumb and Dumber?",
        "answer": "Dumb and Dumber examines themes of friendship, loyalty, and the triumph of the underdog."
    },
    {
        "question": "What themes are prevalent in the movie The Grand Budapest Hotel?",
        "answer": "The Grand Budapest Hotel addresses themes of nostalgia, friendship, and the passing of an era."
    },
    {
        "question": "What is the main focus of the movie Airplane!?",
        "answer": "Airplane! focuses on themes of parody, absurdity, and the conventions of disaster movies."
    },
    {
        "question": "What themes are explored in the movie Shaun of the Dead?",
        "answer": "Shaun of the Dead delves into themes of friendship, maturity, and the zombie apocalypse as a metaphor for modern life."
    },
    {
        "question": "What is the central theme of the movie Ferris Bueller's Day Off?",
        "answer": "Ferris Bueller's Day Off explores themes of rebellion, freedom, and the celebration of youth."
    },
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (444, 2)

# %%
qa_pairs = [
    {
        "question": "What is the central theme of the movie Saving Private Ryan?",
        "answer": "Saving Private Ryan explores themes of sacrifice, duty, and the human cost of war."
    },
    {
        "question": "What is the primary focus of the movie Apocalypse Now?",
        "answer": "Apocalypse Now focuses on themes of madness, morality, and the surreal nature of war."
    },
    {
        "question": "What themes are prevalent in the movie Schindler's List?",
        "answer": "Schindler's List addresses themes of humanity, redemption, and the horrors of the Holocaust."
    },
    {
        "question": "What is the main theme of the movie Full Metal Jacket?",
        "answer": "Full Metal Jacket explores themes of dehumanization, psychological trauma, and the brutal realities of war."
    },
    {
        "question": "What is the central message of the movie Dunkirk?",
        "answer": "Dunkirk examines themes of survival, heroism, and the resilience of the human spirit in the face of adversity."
    },
    {
        "question": "What themes does the movie Platoon tackle?",
        "answer": "Platoon addresses themes of morality, brotherhood, and the psychological impact of war on soldiers."
    },
    {
        "question": "What is the main focus of the movie The Deer Hunter?",
        "answer": "The Deer Hunter focuses on themes of friendship, trauma, and the effects of the Vietnam War on American society."
    },
    {
        "question": "What themes are explored in the movie Hacksaw Ridge?",
        "answer": "Hacksaw Ridge delves into themes of courage, faith, and the power of non-violence in the midst of war."
    },
    {
        "question": "What is the central theme of the movie Letters from Iwo Jima?",
        "answer": "Letters from Iwo Jima explores themes of honor, sacrifice, and the humanity of soldiers on both sides of the conflict."
    },
    {
        "question": "What is the primary theme of the movie Das Boot?",
        "answer": "Das Boot examines themes of camaraderie, claustrophobia, and the brutality of submarine warfare."
    },
    {
        "question": "What themes does the movie The Hurt Locker address?",
        "answer": "The Hurt Locker addresses themes of addiction, risk-taking, and the psychological toll of bomb disposal."
    },
    {
        "question": "What is the central theme of the movie Black Hawk Down?",
        "answer": "Black Hawk Down explores themes of brotherhood, heroism, and the chaos of modern warfare."
    },
    {
        "question": "What is the main theme of the movie 1917?",
        "answer": "1917 examines themes of duty, sacrifice, and the futility of war amidst the backdrop of World War I."
    },
    {
        "question": "What themes are prevalent in the movie The Thin Red Line?",
        "answer": "The Thin Red Line addresses themes of nature, spirituality, and the ambiguity of war."
    },
    {
        "question": "What is the primary focus of the movie Fury?",
        "answer": "Fury focuses on themes of camaraderie, survival, and the moral complexities of war."
    },
    {
        "question": "What themes does the movie Paths of Glory tackle?",
        "answer": "Paths of Glory addresses themes of honor, cowardice, and the injustice of military authority."
    },
    {
        "question": "What is the central theme of the movie A Bridge Too Far?",
        "answer": "A Bridge Too Far explores themes of ambition, sacrifice, and the human cost of failed military operations."
    },
    {
        "question": "What is the main theme of the movie Gallipoli?",
        "answer": "Gallipoli examines themes of friendship, patriotism, and the tragedy of young lives lost in war."
    },
    {
        "question": "What themes are explored in the movie We Were Soldiers?",
        "answer": "We Were Soldiers delves into themes of leadership, sacrifice, and the human dimension of battle."
    },
    {
        "question": "What is the central theme of the movie The Bridge on the River Kwai?",
        "answer": "The Bridge on the River Kwai explores themes of duty, honor, and the clash between personal integrity and military orders."
    },
    {
        "question": "What is the primary focus of the movie Tora! Tora! Tora!?",
        "answer": "Tora! Tora! Tora! focuses on themes of surprise, strategy, and the events leading up to the attack on Pearl Harbor."
    },
    {
        "question": "What themes does the movie Empire of the Sun address?",
        "answer": "Empire of the Sun addresses themes of survival, innocence, and the loss of childhood in the midst of war."
    },
    {
        "question": "What is the central theme of the movie The Pianist?",
        "answer": "The Pianist explores themes of survival, resilience, and the power of music in the face of adversity."
    },
    {
        "question": "What is the main theme of the movie The Great Escape?",
        "answer": "The Great Escape examines themes of camaraderie, resilience, and the indomitable human spirit in the face of captivity."
    },
    {
        "question": "What themes are prevalent in the movie Stalingrad?",
        "answer": "Stalingrad addresses themes of survival, sacrifice, and the brutality of urban warfare."
    },
    {
        "question": "What is the primary focus of the movie Dunkirk?",
        "answer": "Dunkirk focuses on themes of survival, heroism, and the resilience of the human spirit in the face of overwhelming odds."
    },
    {
        "question": "What themes does the movie Fury tackle?",
        "answer": "Fury addresses themes of camaraderie, loyalty, and the moral complexities of war."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (471, 2)

# %%
qa_pairs = [
    {
        "question": "What themes are often depicted in movies set in ancient Egypt?",
        "answer": "Movies set in ancient Egypt often depict themes such as divine kingship, religious rituals, the afterlife, and monumental architecture like pyramids and temples."
    },
    {
        "question": "What are common plotlines in movies set in ancient Greece?",
        "answer": "Movies set in ancient Greece commonly feature plotlines involving epic battles, mythical heroes, quests for glory, the pantheon of Greek gods, and philosophical discourse."
    },
    {
        "question": "How do movies set in ancient Rome portray the Roman Empire?",
        "answer": "Movies set in ancient Rome often portray the Roman Empire as a world of grandeur and excess, with themes of power struggles, political intrigue, gladiatorial combat, and the clash of civilizations."
    },
    {
        "question": "What are some popular movies that depict ancient Mesopotamia?",
        "answer": "Popular movies that depict ancient Mesopotamia include 'The Ten Commandments,' 'The Epic of Gilgamesh,' and 'The Scorpion King,' which explore themes of ancient civilizations, mythic heroes, and epic quests."
    },
    {
        "question": "How do movies set in ancient China depict the dynastic periods?",
        "answer": "Movies set in ancient China often depict the dynastic periods with themes of imperial courts, martial arts, Confucian ethics, and the struggles for power and dominance."
    },
    {
        "question": "What are some common elements in movies set in ancient civilizations?",
        "answer": "Common elements in movies set in ancient civilizations include epic quests, conflicts between gods and mortals, struggles for power and survival, mythological creatures, and the exploration of cultural and religious beliefs."
    },
    {
        "question": "How do movies set in ancient times portray daily life?",
        "answer": "Movies set in ancient times often portray daily life with depictions of ancient cities, markets, temples, rural landscapes, social customs, and the roles of men, women, and children in society."
    },
    {
        "question": "What are some challenges in creating historically accurate ancient movies?",
        "answer": "Challenges in creating historically accurate ancient movies include sourcing authentic costumes, sets, and props; accurately representing ancient languages and customs; and balancing historical authenticity with modern storytelling conventions."
    },
    {
        "question": "How do movies set in ancient times address themes of mythology and legend?",
        "answer": "Movies set in ancient times often address themes of mythology and legend by incorporating mythical creatures, heroic quests, divine interventions, and legendary figures into their narratives."
    },
    {
        "question": "What are some examples of ancient-themed movies that have received critical acclaim?",
        "answer": "Examples of ancient-themed movies that have received critical acclaim include 'Gladiator,' '300,' 'Troy,' 'Apocalypto,' and 'The Passion of the Christ,' which have been praised for their storytelling, visual spectacle, and historical authenticity."
    },
    {
        "question": "How do movies set in ancient civilizations explore the human condition?",
        "answer": "Movies set in ancient civilizations explore the human condition by addressing universal themes such as love, honor, betrayal, redemption, sacrifice, and the search for meaning and identity."
    },
    {
        "question": "What are some differences in the portrayal of ancient cultures in movies compared to historical reality?",
        "answer": "Differences in the portrayal of ancient cultures in movies compared to historical reality include the use of anachronistic language, modern interpretations of customs and beliefs, exaggerations of historical events, and the prioritization of entertainment value over strict adherence to historical accuracy."
    },
    {
        "question": "How do movies set in ancient times handle themes of conquest and empire-building?",
        "answer": "Movies set in ancient times often handle themes of conquest and empire-building by depicting the rise and fall of empires, the exploits of conquerors and rulers, the clashes between civilizations, and the human costs of war and imperialism."
    },
    {
        "question": "What are some examples of ancient-themed movies that have become cultural touchstones?",
        "answer": "Examples of ancient-themed movies that have become cultural touchstones include 'Ben-Hur,' 'Cleopatra,' 'Lawrence of Arabia,' 'The Mummy,' and 'Indiana Jones and the Raiders of the Lost Ark,' which have left a lasting impact on popular culture with their iconic imagery and memorable characters."
    },
    {
        "question": "How do movies set in ancient times reflect the values and beliefs of their respective civilizations?",
        "answer": "Movies set in ancient times reflect the values and beliefs of their respective civilizations by portraying societal norms, religious practices, moral codes, and attitudes towards authority, gender roles, and the supernatural."
    },
    {
        "question": "What are some examples of ancient-themed movies that have sparked controversies or debates?",
        "answer": "Examples of ancient-themed movies that have sparked controversies or debates include 'The Last Temptation of Christ,' 'Exodus: Gods and Kings,' and 'Noah,' which have faced criticism for their interpretations of religious stories and historical accuracy."
    },
    {
        "question": "How do movies set in ancient times use visual and narrative techniques to immerse viewers in the past?",
        "answer": "Movies set in ancient times use visual and narrative techniques such as elaborate sets, costumes, and CGI effects; epic storytelling and sweeping vistas; and sound design and music to create immersive experiences that transport viewers to ancient civilizations."
    },
    {
        "question": "What are some examples of ancient-themed movies that explore lesser-known cultures or periods?",
        "answer": "Examples of ancient-themed movies that explore lesser-known cultures or periods include 'Agora,' 'The Eagle,' 'The New World,' 'Apocalypto,' and 'The 13th Warrior,' which shed light on forgotten civilizations, indigenous cultures, and untold stories from history."
    },
    {
        "question": "How do movies set in ancient times address issues of identity, ethnicity, and cultural diversity?",
        "answer": "Movies set in ancient times address issues of identity, ethnicity, and cultural diversity by depicting interactions between different cultures, the exchange of ideas and technologies, the blending of traditions, and the tensions and conflicts that arise from cultural differences."
    },
    {
        "question": "What are some examples of ancient-themed movies that have inspired archaeological discoveries or research?",
        "answer": "Examples of ancient-themed movies that have inspired archaeological discoveries or research include 'The Mummy,' 'Indiana Jones,' and 'Troy,' which have prompted renewed interest in ancient civilizations, artifacts, and historical sites."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (491, 2)

# %%
qa_pairs = [
    {
        "question": "What are common elements found in fantasy movies?",
        "answer": "Common elements found in fantasy movies include magical creatures, mythical realms, epic quests, heroes and villains, supernatural powers, and the battle between good and evil."
    },
    {
        "question": "How do fantasy movies often explore the theme of heroism?",
        "answer": "Fantasy movies often explore the theme of heroism by featuring protagonists who embark on epic journeys, face formidable challenges, demonstrate courage and selflessness, and ultimately triumph over adversity to save the day."
    },
    {
        "question": "What role do magical creatures play in fantasy movies?",
        "answer": "Magical creatures in fantasy movies serve various roles, from allies and companions to adversaries and obstacles, adding wonder, danger, and intrigue to the story world and enriching the mythology of the fictional universe."
    },
    {
        "question": "How do fantasy movies create immersive fictional worlds?",
        "answer": "Fantasy movies create immersive fictional worlds through elaborate production design, visual effects, world-building, and attention to detail, transporting viewers to fantastical realms filled with unique cultures, landscapes, and inhabitants."
    },
    {
        "question": "What are some subgenres of fantasy movies?",
        "answer": "Subgenres of fantasy movies include high fantasy (set in elaborate secondary worlds), urban fantasy (blending fantastical elements with modern settings), sword and sorcery (featuring heroic adventurers in action-packed quests), fairy tale adaptations, and magical realism (blurring the lines between fantasy and reality)."
    },
    {
        "question": "How do fantasy movies often explore themes of good versus evil?",
        "answer": "Fantasy movies often explore themes of good versus evil by presenting moral dilemmas, ethical conflicts, and battles between virtuous heroes and malevolent villains, reflecting universal struggles and inspiring audiences with messages of hope and resilience."
    },
    {
        "question": "What role do quests play in fantasy movies?",
        "answer": "Quests in fantasy movies serve as narrative frameworks for characters to embark on transformative journeys, seek legendary artifacts or knowledge, overcome personal trials, and fulfill prophecies or destinies, driving the plot forward and providing opportunities for adventure and growth."
    },
    {
        "question": "How do fantasy movies use magic as a storytelling device?",
        "answer": "Fantasy movies use magic as a storytelling device to introduce wonder, mystery, and awe into the narrative, allowing characters to wield supernatural powers, encounter enchanted objects or places, and explore the boundaries of reality and imagination."
    },
    {
        "question": "What are some classic examples of fantasy movies?",
        "answer": "Classic examples of fantasy movies include 'The Lord of the Rings' trilogy, 'Harry Potter' series, 'The Chronicles of Narnia,' 'The Wizard of Oz,' and 'Pan's Labyrinth,' which have captivated audiences with their imaginative worlds, compelling characters, and timeless themes."
    },
    {
        "question": "How do fantasy movies appeal to audiences of all ages?",
        "answer": "Fantasy movies appeal to audiences of all ages by offering escapist entertainment, engaging storytelling, and universal themes that resonate with viewers' imaginations, emotions, and aspirations, fostering a sense of wonder and enchantment for young and old alike."
    },
    {
        "question": "What are some recent trends in fantasy movies?",
        "answer": "Recent trends in fantasy movies include adaptations of popular books, comics, and video games; reimaginings of classic tales with diverse casts and modern sensibilities; the blending of fantasy with other genres such as horror, science fiction, and romance; and the exploration of darker, more mature themes and narratives."
    },
    {
        "question": "How do fantasy movies often explore themes of identity and destiny?",
        "answer": "Fantasy movies often explore themes of identity and destiny by featuring protagonists who grapple with questions of self-discovery, purpose, and fate, confronting their inner demons, embracing their unique gifts or heritage, and realizing their potential to shape their own destinies."
    },
    {
        "question": "What role does world-building play in fantasy movies?",
        "answer": "World-building in fantasy movies involves creating richly detailed and coherent fictional universes, including geography, history, cultures, languages, and mythology, to immerse audiences in the story world and enhance the sense of wonder and believability."
    },
    {
        "question": "How do fantasy movies incorporate elements of folklore and mythology?",
        "answer": "Fantasy movies incorporate elements of folklore and mythology by drawing inspiration from legends, folklore, and mythological tales from around the world, reinterpreting familiar motifs, archetypes, and creatures to create original narratives that resonate with contemporary audiences."
    },
    {
        "question": "What are some memorable examples of magical artifacts in fantasy movies?",
        "answer": "Memorable examples of magical artifacts in fantasy movies include the One Ring from 'The Lord of the Rings,' the Elder Wand from 'Harry Potter,' the Holy Grail from 'Indiana Jones and the Last Crusade,' and the Golden Fleece from 'Jason and the Argonauts,' each possessing unique powers and significance within their respective stories."
    },
    {
        "question": "How do fantasy movies explore themes of courage and heroism?",
        "answer": "Fantasy movies explore themes of courage and heroism by portraying protagonists who exhibit bravery, resilience, and self-sacrifice in the face of adversity, inspiring others to rise above their fears and fight for what is right."
    },
    {
        "question": "What are some examples of memorable fantasy creatures in movies?",
        "answer": "Examples of memorable fantasy creatures in movies include dragons, elves, dwarves, unicorns, griffins, trolls, mermaids, and phoenixes,"
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (508, 2)

# %%
qa_pairs = [
    {
        "question": "What are some popular video game adaptations that have been made into movies?",
        "answer": "Popular video game adaptations that have been made into movies include 'Resident Evil,' 'Tomb Raider,' 'Mortal Kombat,' 'Detective Pikachu,' 'Assassin's Creed,' and 'Sonic the Hedgehog.'"
    },
    {
        "question": "How do movies based on video games often handle the adaptation process?",
        "answer": "Movies based on video games often handle the adaptation process by balancing fidelity to the source material with creative liberties to craft a compelling cinematic experience, incorporating elements of the game's narrative, characters, and aesthetic while adapting them to suit the medium of film."
    },
    {
        "question": "What challenges do filmmakers face when adapting video games into movies?",
        "answer": "Filmmakers face various challenges when adapting video games into movies, including translating interactive gameplay mechanics into a linear narrative structure, capturing the essence of the game's world and characters while appealing to both fans and general audiences, and avoiding pitfalls such as poor storytelling, wooden performances, and overreliance on CGI effects."
    },
    {
        "question": "How do movies based on video games appeal to fans of the original games?",
        "answer": "Movies based on video games appeal to fans of the original games by staying faithful to key aspects of the source material, such as iconic characters, settings, and moments, while expanding upon them with new insights, interpretations, and visual spectacle that enhance the overall experience for dedicated fans."
    },
    {
        "question": "What are some examples of successful video game adaptations that have resonated with audiences?",
        "answer": "Examples of successful video game adaptations that have resonated with audiences include 'Detective Pikachu,' which received praise for its faithful depiction of the Pokémon universe and charismatic performances, and 'Sonic the Hedgehog,' which garnered acclaim for its energetic pacing, humor, and engaging portrayal of the beloved video game character."
    },
    {
        "question": "How do movies based on video games attract viewers who may not be familiar with the original games?",
        "answer": "Movies based on video games attract viewers who may not be familiar with the original games by offering accessible entry points into the story world, compelling characters, and exciting action sequences that stand on their own merits, regardless of prior knowledge or attachment to the source material."
    },
    {
        "question": "What are some common criticisms of movies based on video games?",
        "answer": "Common criticisms of movies based on video games include poor writing, wooden acting, lackluster direction, and a tendency to prioritize spectacle over storytelling, resulting in shallow narratives, underdeveloped characters, and missed opportunities to explore the rich potential of the source material."
    },
    {
        "question": "How do movies based on video games contribute to the broader cultural conversation surrounding gaming?",
        "answer": "Movies based on video games contribute to the broader cultural conversation surrounding gaming by bridging the gap between different forms of entertainment, fostering discussions about the storytelling techniques, visual aesthetics, and immersive experiences of video games, and introducing new audiences to the diverse worlds and narratives of gaming."
    },
    {
        "question": "What are some examples of upcoming video game adaptations that are highly anticipated?",
        "answer": "Examples of upcoming video game adaptations that are highly anticipated include 'Uncharted,' 'The Last of Us,' 'Minecraft,' 'Metal Gear Solid,' and 'Borderlands,' which have generated excitement among fans and curiosity from audiences eager to see how these beloved games translate to the big screen."
    },
    {
        "question": "How do movies based on video games address the interactive nature of gaming?",
        "answer": "Movies based on video games often address the interactive nature of gaming by incorporating references to gameplay mechanics, level design, and player agency into their narratives, while also exploring themes of virtual reality, immersion, and the blurred boundaries between reality and fantasy."
    },
    {
        "question": "What are some examples of video game adaptations that have taken creative liberties with the source material?",
        "answer": "Examples of video game adaptations that have taken creative liberties with the source material include 'Super Mario Bros.,' which reimagined the iconic video game characters in a dystopian urban setting, and 'Street Fighter: The Movie,' which altered character backstories and relationships to fit the narrative of the film."
    },
    {
        "question": "How do movies based on video games navigate the challenge of appealing to both fans and newcomers?",
        "answer": "Movies based on video games navigate the challenge of appealing to both fans and newcomers by striking a balance between honoring the nostalgia and expectations of longtime fans while also providing accessible entry points, engaging narratives, and exciting visuals that captivate audiences unfamiliar with the original games."
    },
    {
        "question": "What are some examples of video game adaptations that have faced backlash from fans?",
        "answer": "Examples of video game adaptations that have faced backlash from fans include 'Super Mario Bros.,' which deviated significantly from the whimsical and colorful world of the video games, and 'Street Fighter: The Legend of Chun-Li,' which was criticized for its shallow characters and departure from the source material."
    },
    {
        "question": "How do movies based on video games capitalize on the nostalgia of fans?",
        "answer": "Movies based on video games capitalize on the nostalgia of fans by featuring iconic characters, settings, and moments from the games, paying homage to beloved elements of gaming culture, and incorporating Easter eggs, references, and callbacks that evoke fond memories and emotional connections to the source material."
    },
    {
        "question": "What are some examples of video game adaptations that have successfully captured the spirit of the original games?",
        "answer": "Examples of video game adaptations that have successfully captured the spirit of the original games include 'Silent Hill,' which recreated the eerie atmosphere and psychological horror of the video game series, and 'Pokémon: Detective Pikachu,' which faithfully brought the world of Pokémon to life with charming characters and imaginative visuals."
    },
    {
        "question": "How do movies based on video games expand upon the lore and mythology of the original games?",
        "answer": "Movies based on video games expand upon the lore and mythology of the original games by delving deeper into the backstory of characters, introducing new plotlines and conflicts, and exploring untold aspects of the game world, enriching the overall narrative and offering fresh insights for fans."
    },
    {
        "question": "What are some examples of video game adaptations that have failed to capture the essence of the original games?",
        "answer": "Examples of video game adaptations that have failed to capture the essence of the original games include 'Doom,' which struggled to translate the fast-paced action and adrenaline of the game into a coherent narrative, and 'Alone in the Dark,' which was criticized for its confusing plot and poor execution."
    },
    {
        "question": "How do movies based on video games leverage the popularity of gaming culture?",
        "answer": "Movies based on video games leverage the popularity of gaming culture by tapping into the enthusiasm, loyalty, and passion of gaming communities, engaging with fans through social media, events, and merchandise, and embracing the shared language, memes, and traditions of gaming culture to create immersive and authentic experiences."
    },
    {
        "question": "What are some examples of video game adaptations that have surprised audiences with their quality?",
        "answer": "Examples of video game adaptations that have surprised audiences with their quality include 'Sonic the Hedgehog,' which received praise for its humor, heart, and faithful depiction of the beloved video game character, and 'Pokémon: Detective Pikachu,' which impressed viewers with its stunning visuals and engaging storyline."
    },
    {
        "question": "How do movies based on video games incorporate elements of gameplay into their narratives?",
        "answer": "Movies based on video games incorporate elements of gameplay into their narratives by depicting action sequences, puzzles, and challenges reminiscent of gameplay mechanics, as well as incorporating visual cues, sound effects, and camera angles that evoke the immersive experience of playing the game."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (528, 2)

# %%
qa_pairs = [
    {
        "question": "What defines a classic movie?",
        "answer": "A classic movie is typically characterized by enduring popularity, critical acclaim, cultural significance, and lasting influence on filmmaking, often transcending its original release to become a timeless masterpiece that continues to resonate with audiences across generations."
    },
    {
        "question": "What are some common genres of classic movies?",
        "answer": "Common genres of classic movies include drama, comedy, romance, musicals, film noir, westerns, science fiction, horror, and epic historical dramas, each with its own distinctive style, themes, and storytelling conventions."
    },
    {
        "question": "How do classic movies differ from contemporary films?",
        "answer": "Classic movies often differ from contemporary films in terms of visual style, pacing, acting techniques, and societal norms, reflecting the cultural attitudes, technological limitations, and artistic sensibilities of their respective eras while also showcasing timeless themes and universal storytelling techniques."
    },
    {
        "question": "What are some examples of classic movies from the silent era?",
        "answer": "Examples of classic movies from the silent era include 'The Birth of a Nation,' 'Metropolis,' 'Nosferatu,' 'The General,' and 'The Kid,' which pioneered cinematic storytelling techniques and laid the groundwork for the future of filmmaking."
    },
    {
        "question": "How do classic movies from the golden age of Hollywood compare to modern cinema?",
        "answer": "Classic movies from the golden age of Hollywood often feature glamorous stars, lavish production values, and carefully crafted narratives that emphasize romance, escapism, and idealized portrayals of American life, offering audiences a nostalgic glimpse into a bygone era of filmmaking."
    },
    {
        "question": "What are some defining characteristics of film noir classics?",
        "answer": "Film noir classics are known for their dark and moody cinematography, morally ambiguous characters, intricate plots, and existential themes, often exploring themes of crime, betrayal, and corruption in urban settings, with femme fatales and hard-boiled detectives at the center of the narrative."
    },
    {
        "question": "How do classic musicals capture the spirit of the golden age of Hollywood?",
        "answer": "Classic musicals capture the spirit of the golden age of Hollywood through dazzling song and dance numbers, vibrant Technicolor visuals, memorable scores, and larger-than-life performances, offering audiences a spectacle of glamour, romance, and joyous escapism amidst the challenges of the Great Depression and World War II."
    },
    {
        "question": "What are some examples of classic movies that have stood the test of time?",
        "answer": "Examples of classic movies that have stood the test of time include 'Casablanca,' 'Gone with the Wind,' 'The Wizard of Oz,' 'Citizen Kane,' 'Singin' in the Rain,' 'Psycho,' 'It's a Wonderful Life,' and 'Some Like It Hot,' which continue to captivate audiences with their timeless stories, memorable characters, and iconic moments."
    },
    {
        "question": "How do classic horror movies evoke fear and suspense?",
        "answer": "Classic horror movies evoke fear and suspense through atmospheric cinematography, chilling sound design, psychological tension, and supernatural or monstrous threats, tapping into primal fears and anxieties while also offering cathartic thrills and macabre entertainment for audiences."
    },
    {
        "question": "What are some examples of classic movies that have left a lasting impact on popular culture?",
        "answer": "Examples of classic movies that have left a lasting impact on popular culture include 'Star Wars,' 'The Godfather,' 'Jaws,' 'Indiana Jones,' 'Back to the Future,' 'E.T. the Extra-Terrestrial,' 'The Shawshank Redemption,' and 'The Sound of Music,' which have become ingrained in the collective consciousness and continue to be celebrated and referenced in various media."
    },
    {
        "question": "How do classic comedies use humor to address social issues?",
        "answer": "Classic comedies use humor to address social issues by employing satire, wit, and absurdity to lampoon conventions, challenge norms, and highlight the absurdities of human behavior, offering audiences a lighthearted yet incisive commentary on society while providing moments of joy and laughter."
    },
    {
        "question": "What are some examples of classic movies that have won multiple Academy Awards?",
        "answer": "Examples of classic movies that have won multiple Academy Awards include 'Gone with the Wind,' 'The Godfather,' 'Titanic,' 'Ben-Hur,' 'West Side Story,' 'The Lord of the Rings: The Return of the King,' and 'Schindler's List,' which have been recognized for their excellence in filmmaking across multiple categories."
    },
    {
        "question": "How do classic westerns reflect American values and mythology?",
        "answer": "Classic westerns reflect American values and mythology by romanticizing the frontier spirit, rugged individualism, and manifest destiny, while also exploring themes of justice, honor, and the clash between civilization and wilderness, with iconic figures such as cowboys, outlaws, and lawmen embodying the ideals and contradictions of the American West."
    },
    {
        "question": "What are some examples of classic movies that have been remade or adapted for modern audiences?",
        "answer": "Examples of classic movies that have been remade or adapted for modern audiences include 'A Star is Born,' 'The Magnificent Seven,' 'Ocean's Eleven,' 'True Grit,' 'The Great Gatsby,' and 'Little Women,' which reimagine timeless stories and characters for contemporary sensibilities while paying homage to their classic predecessors."
    },
    {
        "question": "How do classic dramas explore complex human emotions and relationships?",
        "answer": "Classic dramas explore complex human emotions and relationships through nuanced performances, intricate storytelling, and thought-provoking themes such as love, loss, betrayal, redemption, and the search for meaning, offering audiences insights into the human condition and stirring their hearts and minds with powerful narratives."
    },
    {
        "question": "What are some examples of classic movies that have inspired generations of filmmakers?",
        "answer": "Examples of classic movies that have inspired generations of filmmakers include 'Citizen Kane,' 'Casablanca,' 'The Godfather,' 'Vertigo,' 'The Graduate,' '2001: A Space Odyssey,' and 'Lawrence of Arabia,' which have pushed the boundaries of cinematic artistry and storytelling and continue to serve as touchstones for aspiring directors and artists."
    },
    {
        "question": "How do classic movies address issues of morality and ethics?",
        "answer": "Classic movies address issues of morality and ethics by presenting characters with moral dilemmas, ethical quandaries, and conflicts between right and wrong, challenging audiences to reflect on their own values and beliefs while also providing opportunities for catharsis, redemption, and personal growth."
    },
    {
        "question": "What are some examples of classic movies that have been preserved as cultural treasures?",
        "answer": "Examples of classic movies that have been preserved as cultural treasures include 'Casablanca,' 'The Wizard of Oz,' 'Gone with the Wind,' 'Psycho,' 'Singin' in the Rain,' 'Citizen Kane,' and 'The Godfather,' which have been celebrated for their artistic achievements, historical significance, and enduring impact on the medium of film."
    },
    {
        "question": "How do classic movies from different countries and cultures reflect their unique perspectives and traditions?",
        "answer": "Classic movies from different countries and cultures reflect their unique perspectives and traditions by exploring local customs, historical events, and societal values, while also engaging with universal themes and emotions that transcend cultural boundaries, fostering cross-cultural understanding and appreciation for diverse cinematic traditions."
    },
    {
        "question": "What are some examples of classic movies that have pushed the boundaries of cinematic storytelling?",
        "answer": "Examples of classic movies that have pushed the boundaries of cinematic storytelling include 'Citizen Kane,' '2001: A Space Odyssey,' 'The Godfather,' 'Psycho,' 'Vertigo,' 'Breathless,' and 'Rashomon,' which have experimented with narrative structure, visual style, and thematic depth, inspiring future generations of filmmakers to innovate and explore new artistic horizons."
    },
    {
        "question": "How do classic movies from the silent era communicate emotion and narrative without dialogue?",
        "answer": "Classic movies from the silent era communicate emotion and narrative without dialogue through expressive acting, visual storytelling, intertitles, and musical accompaniment, relying on the power of images, gestures, and editing techniques to convey meaning and evoke emotional responses from audiences."
    },
    {
        "question": "What are some examples of classic movies that have been preserved by organizations dedicated to film preservation?",
        "answer": "Examples of classic movies that have been preserved by organizations dedicated to film preservation include 'Metropolis,' 'Sunrise: A Song of Two Humans,' 'The Passion of Joan of Arc,' 'The Thief of Bagdad,' 'Nosferatu,' and 'The Cabinet of Dr. Caligari,' which have been restored and archived to ensure their longevity and accessibility for future generations."
    },
    {
        "question": "How do classic movies from the golden age of Hollywood reflect the cultural values and aspirations of their time?",
        "answer": "Classic movies from the golden age of Hollywood reflect the cultural values and aspirations of their time by portraying idealized visions of American life, celebrating themes such as romance, adventure, and the pursuit of happiness, and promoting national unity, optimism, and resilience in the face of adversity."
    },
    {
        "question": "What are some examples of classic movies that have influenced other art forms?",
        "answer": "Examples of classic movies that have influenced other art forms include 'Casablanca,' 'The Wizard of Oz,' 'The Godfather,' 'Psycho,' 'Citizen Kane,' 'Gone with the Wind,' and 'Singin' in the Rain,' which have inspired literature, music, theater, fashion, and visual arts, leaving an indelible mark on the cultural landscape."
    },
    {
        "question": "How do classic movies depict the human experience and universal themes?",
        "answer": "Classic movies depict the human experience and universal themes by exploring emotions, relationships, and dilemmas that resonate with audiences across time and culture, offering insights into the human condition and providing solace, inspiration, and enlightenment in the face of life's challenges and uncertainties."
    },
    {
        "question": "What are some examples of classic movies that have been reinterpreted or reimagined for modern audiences?",
        "answer": "Examples of classic movies that have been reinterpreted or reimagined for modern audiences include 'Romeo and Juliet,' 'Pride and Prejudice,' 'A Star is Born,' 'Little Women,' 'The Great Gatsby,' and 'King Kong,' which have been adapted into new films, television series, stage productions, and literary works that offer fresh perspectives on timeless stories and characters."
    },
    {
        "question": "How do classic movies from the silent era and early Hollywood influence contemporary filmmaking?",
        "answer": "Classic movies from the silent era and early Hollywood influence contemporary filmmaking by inspiring filmmakers with their innovative techniques, compelling storytelling, and timeless themes, serving as reference points for cinematography, editing, production design, and narrative structure, and contributing to the evolution of the medium as an art form."
    },
    {
        "question": "What are some examples of classic movies that have been adapted into successful stage productions?",
        "answer": "Examples of classic movies that have been adapted into successful stage productions include 'The Lion King,' 'Chicago,' 'Singin' in the Rain,' 'West Side Story,' 'The Producers,' and 'My Fair Lady,' which have been reimagined for the stage with new choreography, music, and theatrical elements that capture the essence of the original films while offering audiences a fresh perspective on familiar stories."
    },
    {
        "question": "How do classic movies from the golden age of Hollywood celebrate the glamour and escapism of cinema?",
        "answer": "Classic movies from the golden age of Hollywood celebrate the glamour and escapism of cinema through lush production values, glamorous stars, and escapist narratives that transport audiences to exotic locales, romantic worlds, and fantastical realms, providing a respite from the challenges of everyday life and offering a tantalizing glimpse into a world of beauty, adventure, and possibility."
    },
    {
        "question": "What are some examples of classic movies that have been restored and re-released for new audiences?",
        "answer": "Examples of classic movies that have been restored and re-released for new audiences include 'Lawrence of Arabia,' 'Vertigo,' 'The Third Man,' 'Cinema Paradiso,' 'The Red Shoes,' and 'Seven Samurai,' which have been remastered in high definition and screened in theaters, festivals, and special events to introduce younger generations to the timeless beauty and cinematic mastery of these iconic films."
    },
    {
        "question": "How do classic movies from different countries and cultures contribute to the diversity of cinematic storytelling?",
        "answer": "Classic movies from different countries and cultures contribute to the diversity of cinematic storytelling by showcasing unique perspectives, traditions, and aesthetics, enriching the global cinematic landscape with a rich tapestry of languages, cultures, and storytelling traditions that reflect the richness and diversity of human experience."
    },
    {
        "question": "What are some examples of classic movies that have been adapted into successful television series?",
        "answer": "Examples of classic movies that have been adapted into successful television series include 'M*A*S*H,' 'Buffy the Vampire Slayer,' 'Fargo,' 'Westworld,' 'The Odd Couple,' and 'Friday Night Lights,' which have expanded upon the original films with new characters, storylines, and themes that resonate with contemporary audiences while paying homage to their cinematic predecessors."
    },
    {
        "question": "How do classic movies from the silent era and early Hollywood contribute to the evolution of cinematic language and storytelling techniques?",
        "answer": "Classic movies from the silent era and early Hollywood contribute to the evolution of cinematic language and storytelling techniques by pioneering innovations in editing, cinematography, visual effects, and sound design, laying the foundation for future generations of filmmakers to experiment, innovate, and push the boundaries of the medium as an art form."
    },
    {
        "question": "What are some examples of classic movies that have inspired fashion trends and cultural movements?",
        "answer": "Examples of classic movies that have inspired fashion trends and cultural movements include 'Breakfast at Tiffany's,' 'Rebel Without a Cause,' 'Gentlemen Prefer Blondes,' 'Roman Holiday,' 'Funny Face,' and 'The Great Gatsby,' which have influenced clothing styles, haircuts, accessories, and attitudes, leaving an indelible mark on fashion and popular culture."
    },
    {
        "question": "How do classic movies explore themes of identity, belonging, and self-discovery?",
        "answer": "Classic movies explore themes of identity, belonging, and self-discovery by depicting characters who grapple with questions of personal and cultural identity, navigate social expectations and constraints, and embark on journeys of self-discovery, growth, and transformation, offering audiences insights into the complexities of human nature and the search for meaning and fulfillment."
    },
    {
        "question": "What are some examples of classic movies that have been adapted into successful video games?",
        "answer": "Examples of classic movies that have been adapted into successful video games include 'The Godfather,' 'Jurassic Park,' 'Jaws,' 'Alien,' 'Blade Runner,' and 'The Lord of the Rings,' which have allowed players to immerse themselves in the worlds, stories, and characters of these iconic films through interactive gameplay experiences."
    },
    {
        "question": "How do classic movies from the golden age of Hollywood capture the spirit of American optimism and resilience?",
        "answer": "Classic movies from the golden age of Hollywood capture the spirit of American optimism and resilience by presenting stories of triumph over adversity, perseverance in the face of challenges, and the pursuit of dreams and aspirations, reflecting the indomitable spirit and can-do attitude that have defined the American experience throughout history."
    },
    {
        "question": "What are some examples of classic movies that have been adapted into successful Broadway musicals?",
        "answer": "Examples of classic movies that have been adapted into successful Broadway musicals include 'The Sound of Music,' 'The Lion King,' 'Mary Poppins,' 'My Fair Lady,' 'Beauty and the Beast,' and 'Chicago,' which have translated the magic, music, and romance of the original films into unforgettable theatrical experiences that have delighted audiences around the world."
    },
    {
        "question": "How do classic movies address issues of social justice, equality, and human rights?",
        "answer": "Classic movies address issues of social justice, equality, and human rights by shining a light on injustice, discrimination, and oppression, and advocating for compassion, tolerance, and understanding, challenging audiences to confront uncomfortable truths and work towards a more just and equitable society."
    },
    {
        "question": "What are some examples of classic movies that have inspired archaeological discoveries or research?",
        "answer": "Examples of classic movies that have inspired archaeological discoveries or research include 'Raiders of the Lost Ark,' 'The Mummy,' 'Indiana Jones and the Last Crusade,' and 'Troy,' which have prompted renewed interest in ancient civilizations, artifacts, and historical sites."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (568, 2)

# %%
qa_pairs = [
    {
        "question": "What are some defining characteristics of Italian cinema?",
        "answer": "Italian cinema is known for its rich artistic heritage, diverse genres, emphasis on storytelling and character development, and contributions to cinematic movements such as neorealism, surrealism, and the commedia all'italiana (Italian-style comedy), as well as its influence on global filmmaking."
    },
    {
        "question": "How has Italian cinema influenced the world of filmmaking?",
        "answer": "Italian cinema has influenced the world of filmmaking through its innovative storytelling techniques, cinematic styles, and thematic explorations, inspiring directors, writers, and artists around the globe to experiment with new forms of expression, narrative structures, and visual aesthetics."
    },
    {
        "question": "What are some iconic directors associated with Italian cinema?",
        "answer": "Iconic directors associated with Italian cinema include Federico Fellini, Roberto Rossellini, Vittorio De Sica, Luchino Visconti, Michelangelo Antonioni, Sergio Leone, Bernardo Bertolucci, Pier Paolo Pasolini, and Giuseppe Tornatore, among others, each known for their distinctive artistic visions and contributions to the medium of film."
    },
    {
        "question": "How has Italian cinema evolved over time?",
        "answer": "Italian cinema has evolved over time, from the neorealism movement of the post-World War II era, which emphasized realism, social commentary, and the struggles of ordinary people, to the glamorous and stylish films of the Italian New Wave and beyond, exploring diverse themes, genres, and artistic approaches."
    },
    {
        "question": "What are some notable Italian film festivals?",
        "answer": "Notable Italian film festivals include the Venice Film Festival, the oldest film festival in the world, renowned for showcasing innovative and groundbreaking cinema; the Rome Film Fest, which celebrates Italian and international films; and the Torino Film Festival, known for its focus on independent and experimental cinema."
    },
    {
        "question": "How do Italian movies explore themes of love and passion?",
        "answer": "Italian movies explore themes of love and passion through intimate storytelling, emotional depth, and nuanced performances, capturing the complexities of human relationships, desires, and emotions with honesty, sensitivity, and authenticity."
    },
    {
        "question": "What are some classic Italian films that have left a lasting impact on cinema?",
        "answer": "Classic Italian films that have left a lasting impact on cinema include 'La Dolce Vita,' '8½,' 'Bicycle Thieves,' 'Cinema Paradiso,' 'The Leopard,' 'The Bicycle Thief,' 'La Strada,' 'Rome, Open City,' and 'The Great Beauty,' each acclaimed for their artistic excellence, cultural significance, and contributions to the medium of film."
    },
    {
        "question": "How do Italian comedies reflect the unique humor and wit of Italian culture?",
        "answer": "Italian comedies reflect the unique humor and wit of Italian culture through their emphasis on wordplay, slapstick humor, satire, and social commentary, as well as their colorful characters, vibrant settings, and spirited performances that celebrate the joy of life amidst the challenges of everyday existence."
    },
    {
        "question": "What are some examples of Italian movies that have won international acclaim?",
        "answer": "Examples of Italian movies that have won international acclaim include 'Life is Beautiful,' 'Cinema Paradiso,' 'The Great Beauty,' 'La Dolce Vita,' '8½,' 'Bicycle Thieves,' 'The Leopard,' 'La Strada,' 'Rome, Open City,' and 'The Conformist,' which have received accolades from critics, audiences, and award organizations worldwide."
    },
    {
        "question": "How do Italian movies explore themes of family and tradition?",
        "answer": "Italian movies explore themes of family and tradition through intimate portraits of domestic life, generational conflicts, and the bonds that unite families, portraying the joys, sorrows, and complexities of familial relationships with warmth, humor, and emotional honesty."
    },
    {
        "question": "What are some iconic Italian film locations?",
        "answer": "Iconic Italian film locations include Rome, Venice, Florence, Naples, Sicily, Tuscany, and the Amalfi Coast, renowned for their picturesque landscapes, historic landmarks, and vibrant culture, which have served as evocative backdrops for countless Italian and international films."
    },
    {
        "question": "How do Italian movies address issues of social justice, inequality, and political unrest?",
        "answer": "Italian movies address issues of social justice, inequality, and political unrest through provocative storytelling, political satire, and allegorical narratives that challenge the status quo, confront social injustices, and provoke thought and debate about the pressing issues facing Italian society."
    },
    {
        "question": "What are some examples of Italian movies that have been adapted into successful remakes or reimaginings?",
        "answer": "Examples of Italian movies that have been adapted into successful remakes or reimaginings include 'The Italian Job,' 'The Good, the Bad and the Ugly,' 'Swept Away,' 'The Talented Mr. Ripley,' 'Inferno,' 'Cinema Paradiso,' and 'La Dolce Vita,' which have been reinterpreted for new audiences while paying homage to their Italian roots."
    },
    {
        "question": "How do Italian movies from different regions and cultures reflect Italy's diverse cultural heritage?",
        "answer": "Italian movies from different regions and cultures reflect Italy's diverse cultural heritage through their unique dialects, customs, traditions, and landscapes, showcasing the rich tapestry of Italian identity and the regional nuances that contribute to the country's vibrant cultural mosaic."
    },
    {
        "question": "What are some examples of Italian movies that have been critically acclaimed but may be lesser-known to international audiences?",
        "answer": "Examples of Italian movies that have been critically acclaimed but may be lesser-known to international audiences include 'The Conformist,' 'Divorce Italian Style,' 'Le Quattro Volte,' 'The Tree of Wooden Clogs,' 'L'Avventura,' 'Investigation of a Citizen Above Suspicion,' 'Il Postino,' and 'Gomorrah,' each celebrated for their artistic merit, cultural significance, and contributions to Italian cinema."
    },
    {
        "question": "How do Italian horror films explore themes of fear, superstition, and the macabre?",
        "answer": "Italian horror films explore themes of fear, superstition, and the macabre through atmospheric storytelling, stylish visuals, and psychological horror, drawing inspiration from Italian folklore, Gothic literature, and religious iconography to create chilling and suspenseful cinematic experiences."
    },
    {
        "question": "What are some examples of Italian movies that have been recognized for their contributions to LGBTQ+ cinema?",
        "answer": "Examples of Italian movies that have been recognized for their contributions to LGBTQ+ cinema include 'Call Me by Your Name,' 'The Garden of the Finzi-Continis,' 'La Cage aux Folles,' 'Io e Te,' 'The Consequences of Love,' and 'Stromboli,' which have depicted LGBTQ+ characters and themes with sensitivity, empathy, and authenticity."
    },
    {
        "question": "How do Italian movies from the neorealism movement depict the struggles of ordinary people?",
        "answer": "Italian movies from the neorealism movement depict the struggles of ordinary people through raw and unfiltered storytelling, documentary-like cinematography, and a focus on social realism, portraying the harsh realities of post-war Italy and the resilience, dignity, and humanity of its working-class citizens."
    },
    {
        "question": "What are some examples of Italian movies that have explored the immigrant experience?",
        "answer": "Examples of Italian movies that have explored the immigrant experience include 'Mediterraneo,' 'Bread and Chocolate,' 'Gomorrah,' 'Human Capital,' 'The Golden Door,' 'The Great Beauty,' and 'The Tree of Wooden Clogs,' which have depicted the challenges, triumphs, and cultural clashes faced by immigrants in Italy with sensitivity and empathy."
    },
    {
        "question": "How do Italian movies from the commedia all'italiana genre blend humor with social commentary?",
        "answer": "Italian movies from the commedia all'italiana genre blend humor with social commentary by satirizing Italian society, politics, and institutions, exposing hypocrisy, corruption, and moral decay with irreverence, wit, and sharp comedic timing, while also offering insights into the human condition and the absurdities of everyday life."
    },
    {
        "question": "What are some examples of Italian movies that have explored the mafia and organized crime?",
        "answer": "Examples of Italian movies that have explored the mafia and organized crime include 'The Godfather Trilogy,' 'Gomorrah,' 'Il Divo,' 'Donnie Brasco,' 'The Sicilian Clan,' 'The Consequences of Love,' and 'The Traitor,' each offering a gritty and authentic portrayal of the criminal underworld and its impact on Italian society."
    },
    {
        "question": "How do Italian movies from the surrealist movement challenge conventional narrative structures and visual aesthetics?",
        "answer": "Italian movies from the surrealist movement challenge conventional narrative structures and visual aesthetics by embracing dreamlike imagery, symbolic motifs, and nonlinear storytelling techniques, blurring the line between reality and fantasy, and inviting audiences to explore the depths of the subconscious mind."
    },
    {
        "question": "What are some examples of Italian movies that have explored historical events and figures?",
        "answer": "Examples of Italian movies that have explored historical events and figures include 'The Leopard,' 'The Battle of Algiers,' 'The Garden of the Finzi-Continis,' '1900,' 'The Best of Youth,' 'The Conformist,' and 'Ludwig,' which have shed light on pivotal moments in Italian and world history with authenticity, depth, and emotional resonance."
    },
    {
        "question": "How do Italian movies from the post-war era reflect the trauma and resilience of the Italian people?",
        "answer": "Italian movies from the post-war era reflect the trauma and resilience of the Italian people through poignant storytelling, stark imagery, and a focus on the struggles of ordinary individuals to rebuild their lives amidst the devastation of war, offering a testament to the human spirit and the power of hope and resilience."
    },
    {
        "question": "What are some examples of Italian movies that have explored existential themes and philosophical questions?",
        "answer": "Examples of Italian movies that have explored existential themes and philosophical questions include 'La Dolce Vita,' '8½,' 'The Bicycle Thief,' 'La Strada,' 'L'Avventura,' 'Blow-Up,' 'The Passenger,' and 'Journey to Italy,' which have delved into the complexities of human existence, identity, and meaning with depth, nuance, and philosophical insight."
    },
    {
        "question": "How do Italian movies from the golden age of cinema celebrate the beauty and romance of Italy?",
        "answer": "Italian movies from the golden age of cinema celebrate the beauty and romance of Italy through lush cinematography, picturesque landscapes, and evocative settings that showcase the country's rich cultural heritage, artistic legacy, and timeless allure, capturing the essence of la dolce vita (the sweet life) with passion and elegance."
    },
    {
        "question": "What are some examples of Italian movies that have explored themes of betrayal, loyalty, and honor?",
        "answer": "Examples of Italian movies that have explored themes of betrayal, loyalty, and honor include "
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (595, 2)

# %%
qa_pairs = [
    {
        "question": "What are some defining characteristics of Korean cinema?",
        "answer": "Korean cinema is known for its diverse range of genres, including dramas, thrillers, action films, comedies, and historical epics, as well as its bold storytelling, dynamic performances, stylish visuals, and willingness to tackle controversial and thought-provoking themes."
    },
    {
        "question": "How has Korean cinema evolved over time?",
        "answer": "Korean cinema has evolved over time, from the golden age of Korean cinema in the 1950s and 1960s, which produced classic melodramas and historical epics, to the emergence of the Korean New Wave in the late 1990s and early 2000s, which brought international acclaim and recognition to Korean filmmakers and actors."
    },
    {
        "question": "What are some iconic directors associated with Korean cinema?",
        "answer": "Iconic directors associated with Korean cinema include Bong Joon-ho, Park Chan-wook, Kim Ki-duk, Lee Chang-dong, Hong Sang-soo, Kim Jee-woon, and Park Hoon-jung, among others, each known for their unique artistic visions, provocative storytelling, and contributions to the medium of film."
    },
    {
        "question": "How do Korean movies explore themes of family and tradition?",
        "answer": "Korean movies explore themes of family and tradition through intimate portrayals of familial relationships, generational conflicts, and the cultural values and rituals that shape Korean society, offering poignant insights into the complexities of kinship, duty, and identity."
    },
    {
        "question": "What are some classic Korean films that have left a lasting impact on cinema?",
        "answer": "Classic Korean films that have left a lasting impact on cinema include 'Oldboy,' 'Memories of Murder,' 'The Host,' 'A Tale of Two Sisters,' 'Joint Security Area,' 'Spring, Summer, Fall, Winter... and Spring,' 'Mother,' 'The Chaser,' 'Secret Sunshine,' and 'Burning,' each acclaimed for their artistic merit, cultural significance, and contributions to Korean cinema."
    },
    {
        "question": "How do Korean movies from the Korean New Wave address social issues and political tensions?",
        "answer": "Korean movies from the Korean New Wave address social issues and political tensions through bold storytelling, gritty realism, and allegorical narratives that confront issues such as corruption, inequality, injustice, and the division between North and South Korea, offering incisive commentary on the complexities of Korean society and politics."
    },
    {
        "question": "What are some notable Korean film festivals?",
        "answer": "Notable Korean film festivals include the Busan International Film Festival, Asia's largest film festival, which showcases the best of Korean and international cinema; the Jeonju International Film Festival, known for its focus on independent and experimental films; and the Seoul International Film Festival, which celebrates Korean and global cinema."
    },
    {
        "question": "How do Korean movies explore themes of love and romance?",
        "answer": "Korean movies explore themes of love and romance through tender storytelling, emotional depth, and heartfelt performances, capturing the highs and lows of romantic relationships, the joys of falling in love, and the challenges of maintaining intimacy and connection amidst societal pressures and personal struggles."
    },
    {
        "question": "What are some examples of Korean movies that have won international acclaim?",
        "answer": "Examples of Korean movies that have won international acclaim include 'Parasite,' 'The Handmaiden,' 'Burning,' 'Ode to My Father,' 'Train to Busan,' 'Snowpiercer,' 'The Wailing,' 'A Taxi Driver,' 'The Man from Nowhere,' and 'Mother,' which have received accolades from critics, audiences, and award organizations worldwide."
    },
    {
        "question": "How do Korean action movies showcase martial arts and combat?",
        "answer": "Korean action movies showcase martial arts and combat through dynamic choreography, intense fight sequences, and innovative camera work, blending traditional Korean martial arts with modern techniques to create thrilling and visually striking cinematic experiences."
    },
    {
        "question": "What are some examples of Korean movies that have explored the human condition?",
        "answer": "Examples of Korean movies that have explored the human condition include 'Miracle in Cell No. 7,' 'Sunny,' 'A Werewolf Boy,' 'Silenced,' 'My Sassy Girl,' 'Architecture 101,' 'Masquerade,' 'The Classic,' 'The Attorney,' and 'The Age of Shadows,' each offering poignant insights into the complexities of human nature, emotions, and relationships."
    },
    {
        "question": "How do Korean movies from different genres showcase the diversity of Korean cinema?",
        "answer": "Korean movies from different genres showcase the diversity of Korean cinema through their unique storytelling approaches, visual styles, and thematic explorations, ranging from intimate character dramas and thrilling action films to poignant romances and thought-provoking social commentaries."
    },
    {
        "question": "What are some examples of Korean movies that have been adapted from literature?",
        "answer": "Examples of Korean movies that have been adapted from literature include 'The Handmaiden,' based on the novel 'Fingersmith' by Sarah Waters; 'A Bittersweet Life,' inspired by the works of French author Jean-Patrick Manchette; 'Bungee Jumping of Their Own,' based on the novel by Kyung-sook Shin; and 'The Classic,' adapted from a short story by Kwak Jung."
    },
    {
        "question": "How do Korean thrillers create tension and suspense?",
        "answer": "Korean thrillers create tension and suspense through intricate plotting, unexpected twists, and psychological depth, as well as atmospheric cinematography, moody soundscapes, and intense performances that keep audiences on the edge of their seats from beginning to end."
    },
    {
        "question": "What are some examples of Korean movies that have explored the education system and youth culture?",
        "answer": "Examples of Korean movies that have explored the education system and youth culture include 'Class of Lies,' 'The Outlaws,' 'Swing Kids,' 'The Drug King,' 'The Wailing,' 'I Can Speak,' 'The King,' 'Extreme Job,' and 'Seondal: The Man Who Sells the River,' each offering insights into the pressures, challenges, and aspirations of Korean youth."
    },
    {
        "question": "How do Korean movies from the horror genre explore supernatural themes and psychological horror?",
        "answer": "Korean movies from the horror genre explore supernatural themes and psychological horror through atmospheric storytelling, eerie visuals, and chilling sound design, drawing inspiration from Korean folklore, urban legends, and ghost stories to create spine-tingling cinematic experiences."
    },
    {
        "question": "What are some examples of Korean movies that have depicted historical events and figures?",
        "answer": "Examples of Korean movies that have depicted historical events and figures include 'The Admiral: Roaring Currents,' 'Assassination,' 'The Throne,' 'Memories of the Sword,' 'The Fortress,' '1987: When the Day Comes,' 'The Age of Shadows,' 'The Handmaiden,' and 'The Battleship Island,' which have shed light on pivotal moments in Korean history with authenticity and depth."
    },
    {
        "question": "How do Korean movies from the comedy genre blend humor with social commentary?",
        "answer": "Korean movies from the comedy genre blend humor with social commentary by satirizing Korean society, culture, and politics, and exploring issues such as class divisions, gender roles, and generational conflicts with wit, irreverence, and sharp comedic timing."
    },
    {
        "question": "What are some examples of Korean movies that have addressed mental health and emotional well-being?",
        "answer": "Examples of Korean movies that have addressed mental health and emotional well-being include 'A Beautiful Mind,' 'A Moment to Remember,' 'You Are My Sunshine,' 'Be With You,' 'Oasis,' 'Hello Ghost,' 'Always,' 'The Beauty Inside,' 'Secret Sunshine,' and 'My Sassy Girl,' each offering sensitive portrayals of characters coping with various mental health issues and emotional challenges."
    },
    {
        "question": "How do Korean movies from the drama genre explore themes of redemption and forgiveness?",
        "answer": "Korean movies from the drama genre explore themes of redemption and forgiveness through heartfelt storytelling, complex characters, and emotional depth, portraying characters who confront their past mistakes, seek forgiveness, and strive to make amends, offering profound insights into the healing power of compassion and reconciliation."
    },
    {
        "question": "What are some examples of Korean movies that have depicted cross-cultural relationships?",
        "answer": "Examples of Korean movies that have depicted cross-cultural relationships include 'My Sassy Girl,' 'The Harmonium in My Memory,' 'Lost and Found,' 'Joint Security Area,' 'Late Autumn,' 'The Beauty Inside,' 'Finding Mr. Destiny,' 'Secretly, Greatly,' 'Love Fiction,' and 'The Classified File,' each exploring the complexities and challenges of love across cultural boundaries."
    },
    {
        "question": "How do Korean movies from the romance genre capture the magic and beauty of love?",
        "answer": "Korean movies from the romance genre capture the magic and beauty of love through tender storytelling, heartfelt performances, and sweeping visuals, portraying the joys, heartaches, and transformative power of romantic relationships with sincerity, passion, and emotional resonance."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (617, 2)

# %%
qa_pairs = [
    {
        "question": "What are some defining characteristics of science fiction movies?",
        "answer": "Science fiction movies typically explore speculative concepts, futuristic settings, advanced technology, and imagined worlds, often incorporating elements of scientific principles, space exploration, extraterrestrial life, time travel, and dystopian societies."
    },
    {
        "question": "How do science fiction movies speculate about the future of humanity?",
        "answer": "Science fiction movies speculate about the future of humanity by envisioning potential advancements in technology, society, and human evolution, exploring utopian visions of progress, dystopian nightmares, and everything in between."
    },
    {
        "question": "What are some iconic science fiction movies that have left a lasting impact on the genre?",
        "answer": "Iconic science fiction movies that have left a lasting impact on the genre include 'Blade Runner,' '2001: A Space Odyssey,' 'Star Wars,' 'The Matrix,' 'Alien,' 'The Terminator,' 'Jurassic Park,' 'The Day the Earth Stood Still,' 'Inception,' and 'The Fifth Element,' each acclaimed for their visionary storytelling, groundbreaking visual effects, and imaginative world-building."
    },
    {
        "question": "How do science fiction movies explore the potential consequences of scientific advancement?",
        "answer": "Science fiction movies explore the potential consequences of scientific advancement by addressing ethical dilemmas, existential risks, and the unintended consequences of technological innovation, prompting audiences to consider the impact of science and technology on humanity and the world."
    },
    {
        "question": "What are some examples of science fiction movies that have depicted artificial intelligence and robotics?",
        "answer": "Examples of science fiction movies that have depicted artificial intelligence and robotics include 'Ex Machina,' 'Blade Runner,' 'A.I. Artificial Intelligence,' 'I, Robot,' 'The Terminator,' 'Westworld,' 'Her,' 'Bicentennial Man,' and 'RoboCop,' each exploring themes of consciousness, identity, and the ethical implications of creating sentient machines."
    },
    {
        "question": "How do science fiction movies from different cultures and countries offer unique perspectives on the genre?",
        "answer": "Science fiction movies from different cultures and countries offer unique perspectives on the genre by drawing from diverse mythologies, folklore, and cultural traditions, and exploring themes, settings, and narratives that reflect the unique concerns, values, and anxieties of their respective societies."
    },
    {
        "question": "What are some examples of science fiction movies that have depicted space exploration and interstellar travel?",
        "answer": "Examples of science fiction movies that have depicted space exploration and interstellar travel include 'Interstellar,' 'Gravity,' 'Star Trek,' 'The Martian,' 'Arrival,' 'Moon,' '2001: A Space Odyssey,' 'Contact,' 'Apollo 13,' and 'The Right Stuff,' each offering thrilling portrayals of humanity's quest to explore the cosmos and discover the unknown."
    },
    {
        "question": "How do science fiction movies from the cyberpunk subgenre envision future societies dominated by technology?",
        "answer": "Science fiction movies from the cyberpunk subgenre envision future societies dominated by technology, corporate power, and social decay, exploring themes of urbanization, globalization, and the erosion of individual freedoms in a high-tech, dystopian world."
    },
    {
        "question": "What are some examples of science fiction movies that have explored time travel and alternate realities?",
        "answer": "Examples of science fiction movies that have explored time travel and alternate realities include 'Back to the Future,' 'The Terminator,' 'Looper,' 'Donnie Darko,' 'The Butterfly Effect,' 'Primer,' 'Source Code,' 'Edge of Tomorrow,' 'Groundhog Day,' and 'The Matrix,' each offering mind-bending narratives that challenge our perception of time and reality."
    },
    {
        "question": "How do science fiction movies depict the relationship between humanity and extraterrestrial life?",
        "answer": "Science fiction movies depict the relationship between humanity and extraterrestrial life through a variety of lenses, ranging from hopeful encounters with benevolent aliens to harrowing confrontations with hostile invaders, exploring themes of curiosity, fear, communication, and the search for meaning in the cosmos."
    },
    {
        "question": "What are some examples of science fiction movies that have addressed environmental issues and ecological concerns?",
        "answer": "Examples of science fiction movies that have addressed environmental issues and ecological concerns include 'Wall-E,' 'Avatar,' 'Interstellar,' 'Snowpiercer,' 'The Day After Tomorrow,' 'Waterworld,' 'Soylent Green,' 'Mad Max: Fury Road,' 'Children of Men,' and 'Blade Runner 2049,' each offering cautionary tales about the consequences of environmental degradation and the need for sustainable living."
    },
    {
        "question": "How do science fiction movies explore the potential impact of genetic engineering and biotechnology?",
        "answer": "Science fiction movies explore the potential impact of genetic engineering and biotechnology by imagining scenarios in which genetic manipulation and bioengineering lead to unforeseen consequences, ethical dilemmas, and questions about the nature of identity, humanity, and the sanctity of life."
    },
    {
        "question": "What are some examples of science fiction movies that have depicted post-apocalyptic worlds?",
        "answer": "Examples of science fiction movies that have depicted post-apocalyptic worlds include 'Mad Max: Fury Road,' 'The Road,' 'Children of Men,' 'The Book of Eli,' 'Snowpiercer,' '28 Days Later,' 'The Matrix,' 'I Am Legend,' 'The Day After Tomorrow,' and 'Waterworld,' each offering bleak visions of a world ravaged by catastrophe and struggling to survive."
    },
    {
        "question": "How do science fiction movies from the space opera subgenre explore epic battles, political intrigue, and galactic civilizations?",
        "answer": "Science fiction movies from the space opera subgenre explore epic battles, political intrigue, and galactic civilizations through sweeping narratives, grandiose visuals, and epic storytelling, drawing inspiration from mythology, history, and classic adventure tales to create immersive and captivating cinematic experiences."
    },
    {
        "question": "What are some examples of science fiction movies that have addressed social issues and political commentary?",
        "answer": "Examples of science fiction movies that have addressed social issues and political commentary include 'District 9,' 'Elysium,' 'Snowpiercer,' 'Children of Men,' 'Blade Runner,' 'The Matrix,' 'Starship Troopers,' 'V for Vendetta,' 'In Time,' and 'Gattaca,' each using futuristic settings and speculative concepts to explore contemporary concerns about power, inequality, and social justice."
    },
    {
        "question": "How do science fiction movies from the hard science fiction subgenre explore scientific concepts and technological advancements?",
        "answer": "Science fiction movies from the hard science fiction subgenre explore scientific concepts and technological advancements with rigor and attention to detail, often consulting experts in various fields to ensure scientific accuracy and plausibility in their depiction of futuristic technologies and scientific phenomena."
    },
    {
        "question": "What are some examples of science fiction movies that have depicted dystopian societies?",
        "answer": "Examples of science fiction movies that have depicted dystopian societies include 'Blade Runner,' 'The Matrix,' 'Mad Max: Fury Road,' 'Children of Men,' 'Brazil,' 'Snowpiercer,' '1984,' 'The Hunger Games,' 'V for Vendetta,' and 'Metropolis,' each offering chilling visions of oppressive regimes, social decay, and existential despair."
    },
    {
        "question": "How do science fiction movies from the alternate history subgenre imagine alternative timelines and historical events?",
        "answer": "Science fiction movies from the alternate history subgenre imagine alternative timelines and historical events by exploring 'what if' scenarios and reimagining pivotal moments in history, offering speculative narratives that challenge our understanding of the past and the possibilities of the future."
    },
    {
        "question": "What are some examples of science fiction movies that have depicted the singularity and the evolution of artificial intelligence?",
        "answer": "Examples of science fiction movies that have depicted the singularity and the evolution of artificial intelligence include 'Ex Machina,' 'Transcendence,' 'A.I. Artificial Intelligence,' 'Her,' 'Ghost in the Shell,' 'The Matrix,' 'I, Robot,' 'Bicentennial Man,' and 'Westworld,' each exploring themes of consciousness, identity, and the nature of humanity in the age of AI."
    },
    {
        "question": "How do science fiction movies from the soft science fiction subgenre explore philosophical themes and existential questions?",
        "answer": "Science fiction movies from the soft science fiction subgenre explore philosophical themes and existential questions through introspective storytelling, contemplative dialogue, and speculative scenarios that challenge our assumptions about reality, consciousness, and the human condition."
    },
    {
        "question": "What are some examples of science fiction movies that have depicted alien invasions?",
        "answer": "Examples of science fiction movies that have depicted alien invasions include 'Independence Day,' 'War of the Worlds,' 'District 9,' 'Signs,' 'Arrival,' 'The Day the Earth Stood Still,' 'Invasion of the Body Snatchers,' 'Edge of Tomorrow,' 'Battleship,' and 'Mars Attacks!,' each offering thrilling portrayals of humanity's struggle against extraterrestrial threats."
    },
    {
        "question": "How do science fiction movies from the speculative fiction subgenre explore social, cultural, and technological trends?",
        "answer": "Science fiction movies from the speculative fiction subgenre explore social, cultural, and technological trends by extrapolating current developments and imagining their future implications, offering provocative insights into the possibilities and pitfalls of progress and innovation."
    },
    {
        "question": "What are some examples of science fiction movies that have explored the consequences of climate change?",
        "answer": "Examples of science fiction movies that have explored the consequences of climate change include 'Snowpiercer,' 'The Day After Tomorrow,' 'Waterworld,' 'Interstellar,' 'Geostorm,' 'The Road,' 'Mad Max: Fury Road,' 'The Colony,' 'Tomorrowland,' and 'The Core,' each offering dystopian visions of a world grappling with environmental catastrophe."
    },
    {
        "question": "How do science fiction movies explore the potential for human colonization of other planets?",
        "answer": "Science fiction movies explore the potential for human colonization of other planets by envisioning futuristic space exploration missions, terraforming technologies, and the challenges and possibilities of establishing colonies on distant worlds, offering glimpses of humanity's future among the stars."
    },
    {
        "question": "What are some examples of science fiction movies that have explored the intersection of science and spirituality?",
        "answer": "Examples of science fiction movies that have explored the intersection of science and spirituality include 'Contact,' 'Interstellar,' 'The Fountain,' 'Solaris,' '2001: A Space Odyssey,' 'Arrival,' 'The Tree of Life,' 'The Man from Earth,' 'Annihilation,' and 'The Endless,' each offering philosophical reflections on the mysteries of the universe and the nature of existence."
    },
    {
        "question": "How do science fiction movies from the dystopian subgenre depict oppressive regimes and totalitarian societies?",
        "answer": "Science fiction movies from the dystopian subgenre depict oppressive regimes and totalitarian societies through bleak and oppressive settings, authoritarian governments, and surveillance states, exploring themes of resistance, rebellion, and the struggle for freedom and survival."
    },
    {
        "question": "What are some examples of science fiction movies that have depicted the consequences of nuclear war and global conflict?",
        "answer": "Examples of science fiction movies that have depicted the consequences of nuclear war and global conflict include 'Dr. Strangelove,' 'Threads,' 'The Day After,' 'On the Beach,' 'Testament,' 'Mad Max 2: The Road Warrior,' 'The War Game,' 'When the Wind Blows,' 'The Road,' and 'The Quiet Earth,' each offering harrowing portrayals of a world devastated by nuclear catastrophe."
    },
    {
        "question": "How do science fiction movies explore the potential for human enhancement and transhumanism?",
        "answer": "Science fiction movies explore the potential for human enhancement and transhumanism by imagining future technologies, genetic engineering, and cybernetic implants that enhance human capabilities, blur the line between man and machine, and raise profound questions about identity, ethics, and the nature of humanity."
    },
    {
        "question": "What are some examples of science fiction movies that have depicted the impact of technology on society?",
        "answer": "Examples of science fiction movies that have depicted the impact of technology on society include 'Black Mirror: Bandersnatch,' 'Minority Report,' 'Gattaca,' 'Her,' 'The Social Network,' 'The Matrix,' 'Wall-E,' 'Transcendence,' 'The Circle,' and 'Blade Runner,' each offering cautionary tales about the dangers and drawbacks of technological progress."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (646, 2)

# %%
qa_pairs = [
    {
        "question": "What are some defining characteristics of French cinema?",
        "answer": "French cinema is known for its artistic innovation, intellectual depth, and diverse range of genres, including dramas, comedies, romances, thrillers, and art house films, as well as its rich cultural heritage, nuanced storytelling, and contributions to the global film industry."
    },
    {
        "question": "How has French cinema influenced global filmmaking?",
        "answer": "French cinema has influenced global filmmaking through its groundbreaking innovations, influential directors, and iconic films, shaping cinematic trends and movements such as the French New Wave, which revolutionized filmmaking techniques and narrative styles, and inspiring filmmakers around the world with its bold experimentation and artistic vision."
    },
    {
        "question": "Who are some iconic directors associated with French cinema?",
        "answer": "Iconic directors associated with French cinema include François Truffaut, Jean-Luc Godard, Claude Chabrol, Agnès Varda, Jacques Tati, Jean Renoir, Robert Bresson, Eric Rohmer, Louis Malle, and Jean-Pierre Melville, among others, each known for their unique artistic voices, distinctive styles, and contributions to the medium of film."
    },
    {
        "question": "How do French movies explore themes of love and romance?",
        "answer": "French movies explore themes of love and romance through tender storytelling, nuanced performances, and sophisticated dialogue, capturing the complexities of human relationships, the joys of passion, and the challenges of intimacy with sensitivity and emotional depth."
    },
    {
        "question": "What are some classic French films that have left a lasting impact on cinema?",
        "answer": "Classic French films that have left a lasting impact on cinema include 'The 400 Blows,' 'Breathless,' 'The Rules of the Game,' 'Amélie,' 'La Dolce Vita,' 'The Umbrellas of Cherbourg,' 'Belle de Jour,' 'The Red Balloon,' 'Jules and Jim,' and 'The Discreet Charm of the Bourgeoisie,' each celebrated for their artistic merit, cultural significance, and contributions to French cinema."
    },
    {
        "question": "How do French movies from the French New Wave movement challenge traditional filmmaking conventions?",
        "answer": "French movies from the French New Wave movement challenge traditional filmmaking conventions through their innovative techniques, including jump cuts, handheld camerawork, natural lighting, and improvisational acting, as well as their non-linear narratives, existential themes, and self-reflexive storytelling."
    },
    {
        "question": "What are some examples of French movies that have explored social issues and political commentary?",
        "answer": "Examples of French movies that have explored social issues and political commentary include 'La Haine,' 'The Class,' 'Amélie,' 'A Prophet,' 'The Intouchables,' 'Blue Is the Warmest Colour,' 'The Battle of Algiers,' 'The Lives of Others,' and 'Le Havre,' each offering incisive critiques of contemporary society and the human condition."
    },
    {
        "question": "How do French movies from the comedy genre blend humor with social satire?",
        "answer": "French movies from the comedy genre blend humor with social satire by poking fun at societal norms, cultural stereotypes, and human foibles, offering witty observations on the absurdities of everyday life and the complexities of human nature with irreverence and charm."
    },
    {
        "question": "What are some examples of French movies that have depicted historical events and figures?",
        "answer": "Examples of French movies that have depicted historical events and figures include 'The Battle of Algiers,' 'La Vie en Rose,' 'The Diving Bell and the Butterfly,' 'The Last Metro,' 'Marie Antoinette,' 'The Queen Margot,' 'Monsieur Lazhar,' 'Bon Voyage,' and 'The Messenger: The Story of Joan of Arc,' each offering compelling portrayals of pivotal moments in French and world history."
    },
    {
        "question": "How do French movies from the thriller genre create tension and suspense?",
        "answer": "French movies from the thriller genre create tension and suspense through intricate plotting, psychological depth, and atmospheric storytelling, as well as stylish cinematography, moody soundscapes, and dynamic performances that keep audiences on the edge of their seats from beginning to end."
    },
    {
        "question": "What are some examples of French movies that have explored the immigrant experience?",
        "answer": "Examples of French movies that have explored the immigrant experience include 'La Haine,' 'A Prophet,' 'The Secret of the Grain,' 'The Class,' 'The Edge of Heaven,' 'Ali: Fear Eats the Soul,' 'Welcome,' 'Caramel,' and 'Samba,' each offering poignant insights into the challenges, triumphs, and cultural clashes faced by immigrants in France."
    },
    {
        "question": "How do French movies from the romance genre capture the magic and beauty of love?",
        "answer": "French movies from the romance genre capture the magic and beauty of love through evocative storytelling, sensual imagery, and nuanced performances, portraying the passion, longing, and vulnerability of romantic relationships with grace and authenticity."
    },
    {
        "question": "What are some examples of French movies that have depicted existential themes and philosophical questions?",
        "answer": "Examples of French movies that have depicted existential themes and philosophical questions include 'The Seventh Seal,' 'The Trial,' 'Last Year at Marienbad,' 'Breathless,' 'Persona,' 'My Dinner with André,' 'Through a Glass Darkly,' 'Jules and Jim,' and 'Three Colors: Blue,' each offering meditations on the nature of existence, identity, and the search for meaning in a chaotic world."
    },
    {
        "question": "How do French movies from the art house genre challenge audiences with their experimental storytelling and avant-garde aesthetics?",
        "answer": "French movies from the art house genre challenge audiences with their experimental storytelling and avant-garde aesthetics by pushing the boundaries of cinematic form and narrative structure, often blurring the line between reality and fantasy, and inviting viewers to engage with complex themes and visual metaphors in unconventional ways."
    },
    {
        "question": "What are some examples of French movies that have explored the complexities of human relationships?",
        "answer": "Examples of French movies that have explored the complexities of human relationships include 'Blue Is the Warmest Colour,' 'Annie Hall,' 'In the Mood for Love,' 'The 400 Blows,' 'Before Sunrise,' 'Hiroshima Mon Amour,' 'La La Land,' 'Eternal Sunshine of the Spotless Mind,' 'The Apartment,' and 'Amour,' each offering intimate portraits of love, friendship, and connection."
    },
    {
        "question": "How do French movies from the drama genre tackle issues of identity, belonging, and alienation?",
        "answer": "French movies from the drama genre tackle issues of identity, belonging, and alienation through nuanced characterizations, intimate storytelling, and emotional depth, exploring the struggles of individuals to find meaning and connection in a world marked by uncertainty and change."
    },
    {
        "question": "What are some examples of French movies that have explored the complexities of family dynamics?",
        "answer": "Examples of French movies that have explored the complexities of family dynamics include 'A Christmas Tale,' 'The Umbrellas of Cherbourg,' 'A Separation,' 'Three Colors: Red,' 'The Royal Tenenbaums,' 'Fanny and Alexander,' 'The Tree of Life,' 'Wild Tales,' 'The Squid and the Whale,' and 'Tokyo Story,' each offering intimate portraits of familial love, conflict, and reconciliation."
    },
    {
        "question": "How do French movies from the crime genre depict the underworld and the criminal psyche?",
        "answer": "French movies from the crime genre depict the underworld and the criminal psyche with gritty realism, moral ambiguity, and psychological depth, exploring themes of violence, corruption, and the human capacity for redemption amidst the seedy underbelly of society."
    },
    {
        "question": "What are some examples of French movies that have depicted the experience of adolescence?",
        "answer": "Examples of French movies that have depicted the experience of adolescence include 'The 400 Blows,' 'Girlhood,' 'Blue Is the Warmest Colour,' 'Tomboy,' 'An Education,' 'Boyhood,' 'Mustang,' 'La Haine,' 'Moonlight,' and 'The Virgin Suicides,' each offering poignant reflections on the challenges, joys, and discoveries of youth."
    },
    {
        "question": "How do French movies from the biographical genre capture the lives and legacies of historical figures?",
        "answer": "French movies from the biographical genre capture the lives and legacies of historical figures with depth, authenticity, and reverence, offering insightful portraits of artists, leaders, and visionaries who have shaped the course of history and inspired generations."
    },
    {
        "question": "What are some examples of French movies that have depicted the experience of growing old?",
        "answer": "Examples of French movies that have depicted the experience of growing old include 'Amour,' 'The Straight Story,' 'Away from Her,' 'Ikiru,' 'Up,' 'Wild Strawberries,' 'The Best Exotic Marigold Hotel,' 'On Golden Pond,' 'Gran Torino,' and 'Nebraska,' each offering poignant reflections on aging, mortality, and the passage of time."
    },
    {
        "question": "How do French movies from the surrealism genre challenge conventional reality and narrative structure?",
        "answer": "French movies from the surrealism genre challenge conventional reality and narrative structure through dreamlike imagery, symbolic storytelling, and nonlinear narratives, inviting viewers on a journey into the subconscious mind and the realm of the imagination."
    },
    {
        "question": "What are some examples of French movies that have depicted the struggles of artists and creative expression?",
        "answer": "Examples of French movies that have depicted the struggles of artists and creative expression include 'La La Land,' 'Amadeus,' 'Black Swan,' 'Birdman,' 'Whiplash,' 'The Red Shoes,' 'F for Fake,' 'Midnight in Paris,' 'Cinema Paradiso,' and 'Ed Wood,' each offering insights into the sacrifices, obsessions, and triumphs of the artistic life."
    },
    {
        "question": "How do French movies from the psychological thriller genre explore the depths of the human psyche?",
        "answer": "French movies from the psychological thriller genre explore the depths of the human psyche through suspenseful storytelling, intricate plotting, and complex characterizations, delving into the darkest corners of the mind to unravel mysteries and uncover hidden truths."
    },
    {
        "question": "What are some examples of French movies that have depicted the experience of war and its aftermath?",
        "answer": "Examples of French movies that have depicted the experience of war and its aftermath include 'Army of Shadows,' 'The Sorrow and the Pity,' 'Au Revoir les Enfants,' 'La Grande Illusion,' 'The Battle of Algiers,' 'Paths of Glory,' 'Jean de Florette,' 'Grave of the Fireflies,' 'The Red Badge of Courage,' and 'Joyeux Noël,' each offering powerful portrayals of the human cost of conflict and the resilience of the human spirit."
    },
    {
        "question": "How do French movies from the romantic drama genre explore the complexities of love and passion?",
        "answer": "French movies from the romantic drama genre explore the complexities of love and passion through emotional depth, intimate storytelling, and sensual imagery, capturing the ecstasy, heartache, and longing of romantic relationships with poignancy and sensitivity."
    },
    {
        "question": "What are some examples of French movies that have depicted the experience of exile and displacement?",
        "answer": "Examples of French movies that have depicted the experience of exile and displacement include 'The Motorcycle Diaries,' 'Casablanca,' 'Persepolis,' 'An American in Paris,' 'The Immigrant,' 'Refugee,' 'The Other Side of Hope,' 'Limelight,' and 'The Grand Budapest Hotel,' each offering poignant reflections on identity, belonging, and the search for home in a world marked by upheaval and uncertainty."
    },
    {
        "question": "How do French movies from the mystery genre create intrigue and suspense?",
        "answer": "French movies from the mystery genre create intrigue and suspense through enigmatic characters, labyrinthine plots, and atmospheric settings, weaving tales of deception, betrayal, and intrigue that keep audiences guessing until the very end."
    },
    {
        "question": "What are some examples of French movies that have explored themes of sexuality and desire?",
        "answer": "Examples of French movies that have explored themes of sexuality and desire include 'Blue Is the Warmest Colour,' 'Last Tango in Paris,' 'Belle de Jour,' 'In the Realm of the Senses,' 'Betty Blue,' 'The Piano Teacher,' 'The Dreamers,' 'Wild Reeds,' 'Portrait of a Lady on Fire,' and 'La Vie d'Adèle,' each offering bold and unflinching portrayals of human desire and intimacy."
    },
    {
        "question": "How do French movies from the crime drama genre explore the moral complexities of justice and revenge?",
        "answer": "French movies from the crime drama genre explore the moral complexities of justice and revenge through gripping storytelling, morally ambiguous characters, and ethical dilemmas, challenging viewers to confront their own notions of right and wrong in a world where the lines between good and evil are often blurred."
    },
    {
        "question": "What are some examples of French movies that have depicted the experience of living in the city?",
        "answer": "Examples of French movies that have depicted the experience of living in the city include 'Amélie,' 'Paris, je t'aime,' 'La Haine,' 'Cleo from 5 to 7,' 'Subway,' 'Les Misérables,' 'Breathless,' 'The Triplets of Belleville,' 'The Intouchables,' and 'Amele's Poulain,' each offering vibrant portraits of urban life and the diverse communities that inhabit it."
    },
    {
        "question": "How do French movies from the coming-of-age genre explore themes of identity and self-discovery?",
        "answer": "French movies from the coming-of-age genre explore themes of identity and self-discovery through intimate storytelling, authentic performances, and emotional depth, capturing the joys, struggles, and rites of passage experienced by young protagonists as they navigate the challenges of adolescence and embark on the journey to adulthood."
    },
    {
        "question": "What are some examples of French movies that have depicted the experience of living through historical events?",
        "answer": "Examples of French movies that have depicted the experience of living through historical events include 'The Battle of Algiers,' 'Au Revoir les Enfants,' 'The Sorrow and the Pity,' 'Jean de Florette,' 'Joyeux Noël,' 'La Grande Illusion,' 'Army of Shadows,' 'Persepolis,' 'Indochine,' and 'Sarah's Key,' each offering vivid portrayals of ordinary people caught up in the tumult of history."
    },
    {
        "question": "How do French movies from the drama genre explore themes of grief and loss?",
        "answer": "French movies from the drama genre explore themes of grief and loss through intimate storytelling, powerful performances, and emotional depth, portraying the pain, sorrow, and longing experienced by characters grappling with the death of loved ones and the search for meaning in the face of tragedy."
    },
    {
        "question": "What are some examples of French movies that have depicted the experience of living in rural communities?",
        "answer": "Examples of French movies that have depicted the experience of living in rural communities include 'Jean de Florette,' 'Manon des Sources,' 'The Umbrellas of Cherbourg,' 'Asterix and Obelix vs. Caesar,' 'The Return of Martin Guerre,' 'The Horseman on the Roof,' 'The Chorus,' 'Jeanne Dielman, 23 Commerce Quay, 1080 Brussels,' and 'The Measure of a Man,' each offering evocative portraits of life in the French countryside and the unique challenges faced by rural inhabitants."
    },
    {
        "question": "How do French movies from the war drama genre explore the human cost of conflict?",
        "answer": "French movies from the war drama genre explore the human cost of conflict through poignant storytelling, visceral imagery, and emotional depth, portraying the courage, sacrifice, and suffering of soldiers and civilians caught up in the chaos and devastation of war."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (682, 2)

# %%
qa_pairs = [
    {
        "question": "What are some defining characteristics of German cinema?",
        "answer": "German cinema is known for its diverse range of genres, including dramas, comedies, thrillers, and art house films, as well as its exploration of historical themes, complex characters, and existential questions, often marked by a focus on psychological depth, social critique, and visual storytelling."
    },
    {
        "question": "How has German cinema evolved over time?",
        "answer": "German cinema has evolved over time, reflecting the cultural and political shifts of the nation, from the expressionist films of the Weimar era to the gritty realism of post-war cinema, the experimental avant-garde of the 1960s and 1970s, and the contemporary focus on diverse narratives and international co-productions."
    },
    {
        "question": "Who are some influential directors associated with German cinema?",
        "answer": "Influential directors associated with German cinema include Fritz Lang, Werner Herzog, Rainer Werner Fassbinder, Wim Wenders, Volker Schlöndorff, Tom Tykwer, Fatih Akin, Christian Petzold, Maren Ade, and Michael Haneke, among others, each known for their unique artistic vision, bold storytelling, and contributions to the medium of film."
    },
    {
        "question": "How do German movies explore themes of identity and history?",
        "answer": "German movies explore themes of identity and history through nuanced storytelling, introspective characters, and historical reflection, grappling with the legacy of World War II, the division of the country during the Cold War, and the complexities of national and personal identity in a changing world."
    },
    {
        "question": "What are some classic German films that have left a lasting impact on cinema?",
        "answer": "Classic German films that have left a lasting impact on cinema include 'Metropolis,' 'Nosferatu,' 'The Cabinet of Dr. Caligari,' 'Wings of Desire,' 'Downfall,' 'The Lives of Others,' 'Aguirre, the Wrath of God,' 'Run Lola Run,' 'Good Bye Lenin!,' and 'The Marriage of Maria Braun,' each celebrated for their artistic innovation, cultural significance, and contributions to German cinema."
    },
    {
        "question": "How do German movies from the New German Cinema movement challenge cinematic conventions?",
        "answer": "German movies from the New German Cinema movement challenge cinematic conventions through their bold experimentation with narrative structure, visual style, and thematic content, often blurring the line between fiction and reality, and pushing the boundaries of traditional storytelling to create provocative and thought-provoking cinema."
    },
    {
        "question": "What are some examples of German movies that have explored social issues and political commentary?",
        "answer": "Examples of German movies that have explored social issues and political commentary include 'The Lives of Others,' 'Downfall,' 'The Wave,' 'The Baader Meinhof Complex,' 'Good Bye Lenin!,' 'The Edukators,' 'Run Lola Run,' 'The Counterfeiters,' and 'The Tin Drum,' each offering incisive critiques of contemporary society and the human condition."
    },
    {
        "question": "How do German movies from the comedy genre blend humor with social satire?",
        "answer": "German movies from the comedy genre blend humor with social satire by lampooning cultural norms, political institutions, and everyday life, offering witty observations on the absurdities of modern society and the quirks of human behavior with irreverence and charm."
    },
    {
        "question": "What are some examples of German movies that have depicted historical events and figures?",
        "answer": "Examples of German movies that have depicted historical events and figures include 'Downfall,' 'The Lives of Others,' 'The Counterfeiters,' 'The Tin Drum,' 'Das Boot,' 'The Baader Meinhof Complex,' 'The Wave,' 'Good Bye Lenin!,' and 'The Marriage of Maria Braun,' each offering compelling portrayals of pivotal moments in German and world history."
    },
    {
        "question": "How do German movies from the thriller genre create tension and suspense?",
        "answer": "German movies from the thriller genre create tension and suspense through atmospheric storytelling, psychological depth, and immersive visuals, weaving intricate plots, morally ambiguous characters, and unexpected twists that keep audiences on the edge of their seats until the final frame."
    },
    {
        "question": "What are some examples of German movies that have explored the immigrant experience?",
        "answer": "Examples of German movies that have explored the immigrant experience include 'Ali: Fear Eats the Soul,' 'Head-On,' 'The Edge of Heaven,' 'Soul Kitchen,' 'Yella,' 'In the Fade,' 'Good Bye Lenin!,' 'Run Lola Run,' and 'Berlin Blues,' each offering poignant insights into the challenges, triumphs, and cultural clashes faced by immigrants in Germany."
    },
    {
        "question": "How do German movies from the romance genre capture the complexities of love and relationships?",
        "answer": "German movies from the romance genre capture the complexities of love and relationships through tender storytelling, authentic performances, and emotional depth, exploring themes of passion, intimacy, and vulnerability with sensitivity and nuance."
    },
    {
        "question": "What are some examples of German movies that have depicted existential themes and philosophical questions?",
        "answer": "Examples of German movies that have depicted existential themes and philosophical questions include 'Wings of Desire,' 'The Seventh Seal,' 'Nosferatu,' 'Aguirre, the Wrath of God,' 'Metropolis,' 'Run Lola Run,' 'The White Ribbon,' 'The Lives of Others,' and 'Downfall,' each offering meditations on the human condition, morality, and the search for meaning in a chaotic world."
    },
    {
        "question": "How do German movies from the art house genre challenge audiences with their experimental storytelling and avant-garde aesthetics?",
        "answer": "German movies from the art house genre challenge audiences with their experimental storytelling and avant-garde aesthetics by pushing the boundaries of cinematic form and narrative structure, often blurring the line between reality and fiction, and inviting viewers to engage with complex themes and visual metaphors in unconventional ways."
    },
    {
        "question": "What are some examples of German movies that have explored the complexities of human relationships?",
        "answer": "Examples of German movies that have explored the complexities of human relationships include 'The Lives of Others,' 'Downfall,' 'Good Bye Lenin!,' 'Run Lola Run,' 'Head-On,' 'In the Fade,' 'The Counterfeiters,' 'The Edge of Heaven,' and 'Toni Erdmann,' each offering intimate portraits of love, friendship, and connection."
    },
    {
        "question": "How do German movies from the drama genre tackle issues of identity, belonging, and alienation?",
        "answer": "German movies from the drama genre tackle issues of identity, belonging, and alienation through nuanced characterizations, intimate storytelling, and emotional depth, exploring the struggles of individuals to find their place in a rapidly changing world marked by uncertainty and isolation."
    },
    {
        "question": "What are some examples of German movies that have explored the complexities of family dynamics?",
        "answer": "Examples of German movies that have explored the complexities of family dynamics include 'The White Ribbon,' 'Good Bye Lenin!,' 'The Edukators,' 'Toni Erdmann,' 'The Counterfeiters,' 'The Lives of Others,' 'Head-On,' 'Run Lola Run,' 'In the Fade,' and 'The Marriage of Maria Braun,' each offering intimate portraits of familial love, conflict, and reconciliation."
    },
    {
        "question": "How do German movies from the crime genre depict the underworld and the criminal psyche?",
        "answer": "German movies from the crime genre depict the underworld and the criminal psyche with gritty realism, moral ambiguity, and psychological depth, exploring themes of violence, corruption, and the human capacity for redemption amidst the seedy underbelly of society."
    },
    {
        "question": "What are some examples of German movies that have depicted the experience of adolescence?",
        "answer": "Examples of German movies that have depicted the experience of adolescence include 'Run Lola Run,' 'The White Ribbon,' 'Good Bye Lenin!,' 'Head-On,' 'The Edukators,' 'Victoria,' 'Tschick,' 'Wings of Desire,' 'The Lives of Others,' and 'In the Fade,' each offering poignant reflections on the challenges, joys, and discoveries of youth."
    },
    {
        "question": "How do German movies from the biographical genre capture the lives and legacies of historical figures?",
        "answer": "German movies from the biographical genre capture the lives and legacies of historical figures with depth, authenticity, and reverence, offering insightful portraits of artists, leaders, and visionaries who have shaped the course of history and inspired generations."
    },
    {
        "question": "What are some examples of German movies that have depicted the experience of growing old?",
        "answer": "Examples of German movies that have depicted the experience of growing old include 'The White Ribbon,' 'Good Bye Lenin!,' 'The Lives of Others,' 'The Edukators,' 'In the Fade,' 'Victoria,' 'Tschick,' 'Wings of Desire,' 'Head-On,' and 'Run Lola Run,' each offering poignant reflections on aging, mortality, and the passage of time."
    },
    {
        "question": "How do German movies from the surrealism genre challenge conventional reality and narrative structure?",
        "answer": "German movies from the surrealism genre challenge conventional reality and narrative structure through dreamlike imagery, symbolic storytelling, and nonlinear narratives, inviting viewers on a journey into the subconscious mind and the realm of the imagination."
    },
    {
        "question": "What are some examples of German movies that have depicted the struggles of artists and creative expression?",
        "answer": "Examples of German movies that have depicted the struggles of artists and creative expression include 'Wings of Desire,' 'Metropolis,' 'Nosferatu,' 'Aguirre, the Wrath of God,' 'Run Lola Run,' 'Victoria,' 'Tschick,' 'Good Bye Lenin!,' 'The Edukators,' and 'The Counterfeiters,' each offering insights into the sacrifices, obsessions, and triumphs of the artistic life."
    },
    {
        "question": "How do German movies from the psychological thriller genre explore the depths of the human psyche?",
        "answer": "German movies from the psychological thriller genre explore the depths of the human psyche through suspenseful storytelling, intricate plotting, and complex characterizations, delving into the darkest corners of the mind to unravel mysteries and uncover hidden truths."
    },
    {
        "question": "What are some examples of German movies that have depicted the experience of war and its aftermath?",
        "answer": "Examples of German movies that have depicted the experience of war and its aftermath include 'Downfall,' 'The Lives of Others,' 'The Counterfeiters,' 'The Tin Drum,' 'Das Boot,' 'The Baader Meinhof Complex,' 'The Wave,' 'Good Bye Lenin!,' and 'The Marriage of Maria Braun,' each offering powerful portrayals of the human cost of conflict and the resilience of the human spirit."
    },
    {
        "question": "How do German movies from the romantic drama genre explore the complexities of love and passion?",
        "answer": "German movies from the romantic drama genre explore the complexities of love and passion through emotional depth, intimate storytelling, and sensual imagery, capturing the ecstasy, heartache, and longing of romantic relationships with poignancy and sensitivity."
    },
    {
        "question": "What are some examples of German movies that have depicted the experience of exile and displacement?",
        "answer": "Examples of German movies that have depicted the experience of exile and displacement include 'Good Bye Lenin!,' 'The Lives of Others,' 'Run Lola Run,' 'The Counterfeiters,' 'The Edge of Heaven,' 'In the Fade,' 'Victoria,' 'Tschick,' 'Wings of Desire,' and 'Head-On,' each offering poignant reflections on identity, belonging, and the search for home in a world marked by upheaval and uncertainty."
    },
    {
        "question": "How do German movies from the mystery genre create intrigue and suspense?",
        "answer": "German movies from the mystery genre create intrigue and suspense through enigmatic characters, labyrinthine plots, and atmospheric settings, weaving tales of deception, betrayal, and intrigue that keep audiences guessing until the very end."
    },
    {
        "question": "What are some examples of German movies that have explored themes of sexuality and desire?",
        "answer": "Examples of German movies that have explored themes of sexuality and desire include 'The Lives of Others,' 'Run Lola Run,' 'Good Bye Lenin!,' 'Head-On,' 'Victoria,' 'In the Fade,' 'The Edukators,' 'Wings of Desire,' 'Metropolis,' and 'Nosferatu,' each offering bold and unflinching portrayals of human desire and intimacy."
    },
    {
        "question": "How do German movies from the crime drama genre explore the moral complexities of justice and revenge?",
        "answer": "German movies from the crime drama genre explore the moral complexities of justice and revenge through gripping storytelling, morally ambiguous characters, and ethical dilemmas, challenging viewers to confront their own notions of right and wrong in a world where the lines between good and evil are often blurred."
    },
    {
        "question": "What are some examples of German movies that have depicted the experience of living in the city?",
        "answer": "Examples of German movies that have depicted the experience of living in the city include 'Run Lola Run,' 'Victoria,' 'Good Bye Lenin!,' 'Wings of Desire,' 'Metropolis,' 'The Edukators,' 'The Lives of Others,' 'Head-On,' 'In the Fade,' and 'Tschick,' each offering vibrant portraits of urban life and the diverse communities that inhabit it."
    },
    {
        "question": "How do German movies from the coming-of-age genre explore themes of identity and self-discovery?",
        "answer": "German movies from the coming-of-age genre explore themes of identity and self-discovery through intimate storytelling, authentic performances, and emotional depth, capturing the joys, struggles, and rites of passage experienced by young protagonists as they navigate the challenges of adolescence and embark on the journey to adulthood."
    },
    {
        "question": "What are some examples of German movies that have depicted the experience of living through historical events?",
        "answer": "Examples of German movies that have depicted the experience of living through historical events include 'Downfall,' 'The Lives of Others,' 'The Counterfeiters,' 'The Tin Drum,' 'The Baader Meinhof Complex,' 'The Wave,' 'Good Bye Lenin!,' 'Metropolis,' and 'Nosferatu,' each offering vivid portrayals of ordinary people caught up in the tumult of history."
    },
    {
        "question": "How do German movies from the drama genre explore themes of grief and loss?",
        "answer": "German movies from the drama genre explore themes of grief and loss through intimate storytelling, powerful performances, and emotional depth, portraying the pain, sorrow, and longing experienced by characters grappling with the death of loved ones and the search for meaning in the face of tragedy."
    },
    {
        "question": "What are some examples of German movies that have depicted the experience of living in rural communities?",
        "answer": "Examples of German movies that have depicted the experience of living in rural communities include 'The White Ribbon,' 'Good Bye Lenin!,' 'The Lives of Others,' 'The Edukators,' 'Victoria,' 'Tschick,' 'Wings of Desire,' 'Head-On,' 'Run Lola Run,' and 'In the Fade,' each offering evocative portraits of life in the German countryside and the unique challenges faced by rural inhabitants."
    },
    {
        "question": "How do German movies from the war drama genre explore the human cost of conflict?",
        "answer": "German movies from the war drama genre explore the human cost of conflict through poignant storytelling, visceral imagery, and emotional depth, portraying the courage, sacrifice, and suffering of soldiers and civilians caught up in the chaos and devastation of war."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (718, 2)

# %%
qa_pairs = [
    {
        "question": "What are some defining characteristics of Thai cinema?",
        "answer": "Thai cinema is known for its vibrant storytelling, colorful visuals, and diverse genres, including action, comedy, horror, and drama. It often incorporates elements of Thai culture, folklore, and spirituality, providing unique insights into the traditions and customs of the country."
    },
    {
        "question": "How has Thai cinema evolved over time?",
        "answer": "Thai cinema has evolved over time, reflecting the social, political, and cultural changes in Thailand. From the golden age of Thai cinema in the 1950s and 1960s to the modern era of international recognition, Thai filmmakers have experimented with different styles and narratives, contributing to the richness and diversity of Thai cinema."
    },
    {
        "question": "Who are some influential directors associated with Thai cinema?",
        "answer": "Influential directors associated with Thai cinema include Apichatpong Weerasethakul, Wisit Sasanatieng, Pen-Ek Ratanaruang, Sopon Sukdapisit, and Prachya Pinkaew, among others, each known for their unique artistic vision, storytelling techniques, and contributions to the Thai film industry."
    },
    {
        "question": "How do Thai movies explore themes of identity and cultural heritage?",
        "answer": "Thai movies explore themes of identity and cultural heritage by drawing on traditional Thai beliefs, customs, and folklore, as well as contemporary issues facing Thai society. They often depict the struggles of individuals to reconcile modernity with tradition, and the importance of preserving Thai culture in a rapidly changing world."
    },
    {
        "question": "What are some classic Thai films that have left a lasting impact on cinema?",
        "answer": "Classic Thai films that have left a lasting impact on cinema include 'Tropical Malady,' 'Uncle Boonmee Who Can Recall His Past Lives,' 'Ong-Bak: Muay Thai Warrior,' 'The Iron Ladies,' 'Syndromes and a Century,' 'Last Life in the Universe,' 'Tears of the Black Tiger,' 'The Adventure of Iron Pussy,' and 'Bangkok Dangerous,' each celebrated for their artistic innovation, cultural significance, and contributions to Thai cinema."
    },
    {
        "question": "How do Thai movies from the New Wave movement challenge cinematic conventions?",
        "answer": "Thai movies from the New Wave movement challenge cinematic conventions by exploring unconventional storytelling techniques, experimental narratives, and themes of identity, sexuality, and politics. They often push the boundaries of traditional Thai cinema, offering bold and provocative visions of contemporary Thailand."
    },
    {
        "question": "What are some examples of Thai movies that have explored social issues and political commentary?",
        "answer": "Examples of Thai movies that have explored social issues and political commentary include 'Syndromes and a Century,' 'Uncle Boonmee Who Can Recall His Past Lives,' 'Citizen Dog,' 'The Iron Ladies,' 'The Tin Mine,' 'The Overture,' 'Election,' 'Shutter,' and 'Bangkok Traffic (Love) Story,' each offering insightful critiques of Thai society and the human condition."
    },
    {
        "question": "How do Thai movies from the comedy genre blend humor with cultural references?",
        "answer": "Thai movies from the comedy genre blend humor with cultural references by poking fun at Thai customs, traditions, and everyday life. They often feature exaggerated characters, slapstick comedy, and witty dialogue, providing audiences with a humorous look at the quirks and idiosyncrasies of Thai culture."
    },
    {
        "question": "What are some examples of Thai movies that have depicted historical events and figures?",
        "answer": "Examples of Thai movies that have depicted historical events and figures include 'The Legend of Suriyothai,' 'The Tin Mine,' 'King Naresuan,' 'Bang Rajan,' 'Suriyothai,' 'Queens of Langkasuka,' 'The Siam Renaissance,' 'The Overture,' and 'Nang Nak,' each offering compelling portrayals of Thailand's rich history and cultural heritage."
    },
    {
        "question": "How do Thai movies from the thriller genre create tension and suspense?",
        "answer": "Thai movies from the thriller genre create tension and suspense through fast-paced storytelling, unexpected plot twists, and atmospheric settings. They often explore themes of crime, corruption, and moral ambiguity, keeping audiences on the edge of their seats with gripping narratives and thrilling action sequences."
    },
    {
        "question": "What are some examples of Thai movies that have explored the immigrant experience?",
        "answer": "Examples of Thai movies that have explored the immigrant experience include 'Last Life in the Universe,' 'Syndromes and a Century,' 'Uncle Boonmee Who Can Recall His Past Lives,' 'Citizen Dog,' 'Bangkok Dangerous,' 'Monrak Transistor,' 'Wonderful Town,' 'Shutter,' and 'The Adventure of Iron Pussy,' each offering poignant insights into the challenges, triumphs, and cultural clashes faced by immigrants in Thailand."
    },
    {
        "question": "How do Thai movies from the romance genre capture the complexities of love and relationships?",
        "answer": "Thai movies from the romance genre capture the complexities of love and relationships through heartfelt storytelling, authentic performances, and emotional depth. They often explore themes of love, longing, and heartbreak, depicting the joys and struggles of romantic relationships with sensitivity and nuance."
    },
    {
        "question": "What are some examples of Thai movies that have depicted existential themes and philosophical questions?",
        "answer": "Examples of Thai movies that have depicted existential themes and philosophical questions include 'Tropical Malady,' 'Uncle Boonmee Who Can Recall His Past Lives,' 'Syndromes and a Century,' 'Last Life in the Universe,' 'Blissfully Yours,' 'Cemetery of Splendor,' 'Mysterious Object at Noon,' 'Mundane History,' and 'Wonderful Town,' each offering meditations on the human condition, mortality, and the search for meaning in life."
    },
    {
        "question": "How do Thai movies from the art house genre challenge audiences with their experimental storytelling and visual aesthetics?",
        "answer": "Thai movies from the art house genre challenge audiences with their experimental storytelling and visual aesthetics by pushing the boundaries of cinematic form and narrative structure. They often employ non-linear narratives, surreal imagery, and minimalist aesthetics to create thought-provoking and visually stunning cinema."
    },
    {
        "question": "What are some examples of Thai movies that have explored the complexities of human relationships?",
        "answer": "Examples of Thai movies that have explored the complexities of human relationships include 'Tropical Malady,' 'Uncle Boonmee Who Can Recall His Past Lives,' 'Syndromes and a Century,' 'Last Life in the Universe,' 'Blissfully Yours,' 'Monrak Transistor,' 'Citizen Dog,' 'Shutter,' and 'Wonderful Town,' each offering intimate portraits of love, friendship, and connection."
    },
    {
        "question": "How do Thai movies from the drama genre tackle issues of identity, belonging, and cultural heritage?",
        "answer": "Thai movies from the drama genre tackle issues of identity, belonging, and cultural heritage through nuanced storytelling, rich characterizations, and emotional depth. They often explore the struggles of individuals to find their place in society, reconcile conflicting identities, and preserve their cultural heritage in a rapidly changing world."
    },
    {
        "question": "What are some examples of Thai movies that have explored the complexities of family dynamics?",
        "answer": "Examples of Thai movies that have explored the complexities of family dynamics include 'Uncle Boonmee Who Can Recall His Past Lives,' 'Last Life in the Universe,' 'Monrak Transistor,' 'Shutter,' 'The Tin Mine,' 'The Iron Ladies,' 'Bangkok Dangerous,' 'The Adventure of Iron Pussy,' and 'Bang Rajan,' each offering intimate portraits of familial love, conflict, and reconciliation."
    },
    {
        "question": "How do Thai movies from the crime genre depict the underworld and criminal activities?",
        "answer": "Thai movies from the crime genre depict the underworld and criminal activities with gritty realism, moral ambiguity, and dramatic flair. They often explore themes of corruption, violence, and redemption, offering audiences a glimpse into the seedy underbelly of Thai society."
    },
    {
        "question": "What are some examples of Thai movies that have depicted the experience of adolescence?",
        "answer": "Examples of Thai movies that have depicted the experience of adolescence include 'Citizen Dog,' 'Last Life in the Universe,' 'Shutter,' 'Monrak Transistor,' 'Wonderful Town,' 'Bangkok Dangerous,' 'In the Mood for Love... at 40,' 'Fan Chan,' 'Hello Stranger,' and 'Jan Dara,' each offering poignant reflections on the challenges, joys, and discoveries of youth."
    },
    {
        "question": "How do Thai movies from the biographical genre capture the lives and legacies of historical figures?",
        "answer": "Thai movies from the biographical genre capture the lives and legacies of historical figures with depth, authenticity, and reverence. They often depict the struggles, triumphs, and contributions of prominent figures in Thai history, offering audiences a deeper understanding of their impact on society."
    },
    {
        "question": "What are some examples of Thai movies that have depicted the experience of growing old?",
        "answer": "Examples of Thai movies that have depicted the experience of growing old include 'Uncle Boonmee Who Can Recall His Past Lives,' 'Last Life in the Universe,' 'The Tin Mine,' 'The Iron Ladies,' 'Monrak Transistor,' 'The Adventure of Iron Pussy,' 'Mundane History,' 'Shutter,' and 'The Overture,' each offering poignant reflections on aging, mortality, and the passage of time."
    },
    {
        "question": "How do Thai movies from the surrealism genre challenge conventional reality and narrative structure?",
        "answer": "Thai movies from the surrealism genre challenge conventional reality and narrative structure through dreamlike imagery, symbolic storytelling, and nonlinear narratives. They often blur the line between reality and fantasy, inviting audiences on a journey into the subconscious mind and the realm of the imagination."
    },
    {
        "question": "What are some examples of Thai movies that have depicted the struggles of artists and creative expression?",
        "answer": "Examples of Thai movies that have depicted the struggles of artists and creative expression include 'Syndromes and a Century,' 'Uncle Boonmee Who Can Recall His Past Lives,' 'Tropical Malady,' 'Last Life in the Universe,' 'Cemetery of Splendor,' 'Mysterious Object at Noon,' 'Citizen Dog,' 'Shutter,' and 'Wonderful Town,' each offering insights into the sacrifices, obsessions, and triumphs of the artistic life."
    },
    {
        "question": "How do Thai movies from the psychological thriller genre explore the depths of the human psyche?",
        "answer": "Thai movies from the psychological thriller genre explore the depths of the human psyche through suspenseful storytelling, intricate plotting, and complex characterizations. They often delve into the darkest corners of the mind, probing the motivations and desires that drive individuals to extreme behavior."
    },
    {
        "question": "What are some examples of Thai movies that have depicted the experience of war and its aftermath?",
        "answer": "Examples of Thai movies that have depicted the experience of war and its aftermath include 'The Tin Mine,' 'Bang Rajan,' 'Suriyothai,' 'The Siam Renaissance,' 'Queens of Langkasuka,' 'The Legend of Suriyothai,' 'The Adventure of Iron Pussy,' 'The Overture,' and 'Nang Nak,' each offering powerful portrayals of the human cost of conflict and the resilience of the human spirit."
    },
    {
        "question": "How do Thai movies from the romantic drama genre explore the complexities of love and passion?",
        "answer": "Thai movies from the romantic drama genre explore the complexities of love and passion through emotional depth, intimate storytelling, and sensual imagery. They often depict the joys and heartaches of romantic relationships, capturing the intensity of desire and the longing for connection."
    },
    {
        "question": "What are some examples of Thai movies that have depicted the experience of exile and displacement?",
        "answer": "Examples of Thai movies that have depicted the experience of exile and displacement include 'Last Life in the Universe,' 'Uncle Boonmee Who Can Recall His Past Lives,' 'Syndromes and a Century,' 'Citizen Dog,' 'Bangkok Dangerous,' 'Shutter,' 'Wonderful Town,' 'The Overture,' and 'Nang Nak,' each offering poignant reflections on identity, belonging, and the search for home in a world marked by upheaval and uncertainty."
    },
    {
        "question": "How do Thai movies from the mystery genre create intrigue and suspense?",
        "answer": "Thai movies from the mystery genre create intrigue and suspense through enigmatic characters, labyrinthine plots, and atmospheric settings. They often weave tales of deception, betrayal, and intrigue that keep audiences guessing until the very end."
    },
    {
        "question": "What are some examples of Thai movies that have explored themes of sexuality and desire?",
        "answer": "Examples of Thai movies that have explored themes of sexuality and desire include 'Tropical Malady,' 'Last Life in the Universe,' 'Uncle Boonmee Who Can Recall His Past Lives,' 'Citizen Dog,' 'Monrak Transistor,' 'Shutter,' 'Wonderful Town,' 'In the Mood for Love... at 40,' and 'Jan Dara,' each offering bold and unflinching portrayals of human desire and intimacy."
    },
    {
        "question": "How do Thai movies from the crime drama genre explore the moral complexities of justice and revenge?",
        "answer": "Thai movies from the crime drama genre explore the moral complexities of justice and revenge through gripping storytelling, morally ambiguous characters, and ethical dilemmas. They often challenge viewers to confront their own notions of right and wrong in a world where the lines between good and evil are often blurred."
    },
    {
        "question": "What are some examples of Thai movies that have depicted the experience of living in the city?",
        "answer": "Examples of Thai movies that have depicted the experience of living in the city include 'Last Life in the Universe,' 'Citizen Dog,' 'Bangkok Dangerous,' 'Wonderful Town,' 'The Adventure of Iron Pussy,' 'Fan Chan,' 'Monrak Transistor,' 'Shutter,' and 'Jan Dara,' each offering vibrant portraits of urban life and the diverse communities that inhabit it."
    },
    {
        "question": "How do Thai movies from the coming-of-age genre explore themes of identity and self-discovery?",
        "answer": "Thai movies from the coming-of-age genre explore themes of identity and self-discovery through intimate storytelling, authentic performances, and emotional depth. They often depict the struggles and triumphs of young protagonists as they navigate the challenges of adolescence and embark on the journey to adulthood."
    },
    {
        "question": "What are some examples of Thai movies that have depicted the experience of living through historical events?",
        "answer": "Examples of Thai movies that have depicted the experience of living through historical events include 'The Legend of Suriyothai,' 'The Tin Mine,' 'King Naresuan,' 'Bang Rajan,' 'Suriyothai,' 'Queens of Langkasuka,' 'The Siam Renaissance,' 'The Overture,' and 'Nang Nak,' each offering vivid portrayals of ordinary people caught up in the tumult of history."
    },
    {
        "question": "How do Thai movies from the drama genre explore themes of grief and loss?",
        "answer": "Thai movies from the drama genre explore themes of grief and loss through intimate storytelling, powerful performances, and emotional depth. They often portray the pain, sorrow, and longing experienced by characters grappling with the death of loved ones and the search for meaning in the face of tragedy."
    },
    {
        "question": "What are some examples of Thai movies that have depicted the experience of living in rural communities?",
        "answer": "Examples of Thai movies that have depicted the experience of living in rural communities include 'The Tin Mine,' 'Bang Rajan,' 'Suriyothai,' 'The Siam Renaissance,' 'Queens of Langkasuka,' 'The Legend of Suriyothai,' 'Nang Nak,' 'The Overture,' and 'Monrak Transistor,' each offering evocative portraits of life in rural Thailand and the unique challenges faced by rural inhabitants."
    },
    {
        "question": "How do Thai movies from the war drama genre explore the human cost of conflict?",
        "answer": "Thai movies from the war drama genre explore the human cost of conflict through poignant storytelling, visceral imagery, and emotional depth. They often depict the courage, sacrifice, and suffering of soldiers and civilians caught up in the chaos and devastation of war."
    },
    {
        "question": "What are some examples of Thai movies that have depicted the struggle for LGBTQ+ rights?",
        "answer": "Examples of Thai movies that have depicted the struggle for LGBTQ+ rights include 'The Iron Ladies,' 'The Adventure of Iron Pussy,' 'Love of Siam,' 'Beautiful Boxer,' 'Yes or No,' 'The Wedding Ceremony,' 'Fathers,' 'Fuwajuan and the Forest Spirit,' 'Saturnalia,' and 'Mundane History,' each offering poignant reflections on love, identity, and acceptance."
    },
    {
        "question": "How do Thai movies from the fantasy genre transport audiences to magical worlds and mythical realms?",
        "answer": "Thai movies from the fantasy genre transport audiences to magical worlds and mythical realms through imaginative storytelling, breathtaking visuals, and fantastical creatures. They often draw inspiration from Thai folklore and legends, weaving tales of adventure, heroism, and wonder that captivate the imagination."
    },
    {
        "question": "What are some examples of Thai movies that have depicted the experience of disability?",
        "answer": "Examples of Thai movies that have depicted the experience of disability include 'The Iron Ladies,' 'The Adventure of Iron Pussy,' 'Saturnalia,' 'Satree Lek,' 'Yam Yasothon,' 'Lek and the Asian Elephant,' 'The Pool,' 'Saving Private Tootsie,' 'Handle Me with Care,' and 'Dearest Sister,' each offering sensitive portrayals of characters living with physical or mental disabilities."
    },
    {
        "question": "How do Thai movies from the horror genre create fear and suspense?",
        "answer": "Thai movies from the horror genre create fear and suspense through atmospheric storytelling, supernatural elements, and eerie sound design. They often draw on Thai folklore and urban legends, tapping into universal fears and anxieties to terrify audiences and leave them on the edge of their seats."
    },
    {
        "question": "What are some examples of Thai movies that have depicted the experience of living with mental illness?",
        "answer": "Examples of Thai movies that have depicted the experience of living with mental illness include 'Shutter,' 'Uncle Boonmee Who Can Recall His Past Lives,' 'Last Life in the Universe,' 'The Tin Mine,' 'The Iron Ladies,' 'Monrak Transistor,' 'The Pool,' 'Snap,' 'The 10 Conditions of Love,' and 'Nang Nak,' each offering poignant insights into the challenges, stigmas, and misconceptions surrounding mental health."
    }
]
df = pd.DataFrame(qa_pairs)
df_existing_csv = pd.read_csv(file_path)
df_combined = pd.concat([df_existing_csv, df], ignore_index=True)
df_combined.to_csv(file_path, index=False)
df_combined.shape
# Out:
# (759, 2)
